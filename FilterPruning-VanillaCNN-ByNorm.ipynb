# %%
import tensorflow as tf
import numpy as np
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import clone_model
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from numpy.random import default_rng
from tensorflow.keras.models import load_model
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
plt.imshow(train_images[0])

# %%
num_classes = 10
train_labels = to_categorical(train_labels, num_classes)
test_labels = to_categorical(test_labels, num_classes)

# %%
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

# %%
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.flatten()

for img, lbl, ax in zip(train_images, train_labels, axes):
    ax.imshow(img)
    ax.set_title(f'Label: {lbl}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %%
'''model_list = []

for i in range(10):
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3), name='conv1'),
        MaxPooling2D((2,2), name='pool1'),
        Conv2D(64, (3,3), activation='relu', name='conv2'),
        MaxPooling2D((2,2), name='pool2'),
        Conv2D(64, (3,3), activation='relu', name='conv3'),
        Flatten(name='flatten'),
        Dense(64, activation='relu', name='fc1'),
        Dense(10, activation='softmax', name='output')
        ])
    model_list.append(model)'''
model = Sequential([
        Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3), name='conv1'),
        MaxPooling2D((2,2), name='pool1'),
        Dropout(0.25),
        Conv2D(64, (3,3), activation='relu', padding='same', name='conv2'),
        MaxPooling2D((2,2), name='pool2'),
        Dropout(0.25),
        Conv2D(64, (3,3), activation='relu', padding='same',  name='conv3'),
        MaxPooling2D((2,2), name='pool3'),
        Dropout(0.25),
        Conv2D(128, (3,3), activation='relu', padding='same',  name='conv4'),
        MaxPooling2D((2,2), name='pool4'),
        Dropout(0.25),
        #Conv2D(128, (3,3), activation='relu', padding='same', name='conv5'),
        Flatten(name='flatten'),
        Dense(64, activation='relu', name='fc1'),
        Dense(10, activation='softmax', name='output')
        ])
# Out:
# /Users/amiruladlilhakim/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1 (Conv2D)                  │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool1 (MaxPooling2D)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool2 (MaxPooling2D)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool3 (MaxPooling2D)            │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4 (Conv2D)                  │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool4 (MaxPooling2D)            │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 64)             │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 163,658 (639.29 KB)
#  Trainable params: 163,658 (639.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
def get_flops(model, input_shape):
    # Create a concrete function from the Keras model
    @tf.function
    def model_func(x):
        return model(x)
    
    # Get the concrete function
    concrete_func = model_func.get_concrete_function(tf.TensorSpec(input_shape, model.inputs[0].dtype))
    
    # Convert variables to constants and get the frozen graph
    frozen_func = convert_variables_to_constants_v2(concrete_func)
    frozen_graph = frozen_func.graph.as_graph_def()
    
    # Use TensorFlow's profiler
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(frozen_graph, name='')
        run_meta = tf.compat.v1.RunMetadata()
        with tf.compat.v1.Session(graph=graph) as sess:
            flops = tf.compat.v1.profiler.profile(
                graph=graph,
                run_meta=run_meta,
                cmd='op',
                options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
            )
            return flops.total_float_ops

# %%
'''for i in model_list:
    i.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    i.fit(X, y_one_hot, epochs=100, batch_size=2)
    loss_list.append(i.evaluate(X, y_one_hot)[0])
    accuracy_list.append(i.evaluate(X, y_one_hot)[1])'''
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, epochs=100, batch_size=64, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.2776 - loss: 1.9238 - val_accuracy: 0.4667 - val_loss: 1.4632
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.4690 - loss: 1.4566 - val_accuracy: 0.5401 - val_loss: 1.2809
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.5395 - loss: 1.2711 - val_accuracy: 0.5851 - val_loss: 1.1690
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.5790 - loss: 1.1627 - val_accuracy: 0.6474 - val_loss: 1.0093
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.6123 - loss: 1.0829 - val_accuracy: 0.6651 - val_loss: 0.9547
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.6404 - loss: 1.0181 - val_accuracy: 0.6824 - val_loss: 0.9092
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.6556 - loss: 0.9702 - val_accuracy: 0.6791 - val_loss: 0.9108
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.6731 - loss: 0.9285 - val_accuracy: 0.7041 - val_loss: 0.8466
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.6795 - loss: 0.8985 - val_accuracy: 0.7109 - val_loss: 0.8200
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.6904 - loss: 0.8715 - val_accuracy: 0.7267 - val_loss: 0.7791
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 36ms/step - accuracy: 0.7020 - loss: 0.8337 - val_accuracy: 0.7224 - val_loss: 0.8000
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7095 - loss: 0.8273 - val_accuracy: 0.7230 - val_loss: 0.7878
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.7138 - loss: 0.8098 - val_accuracy: 0.7353 - val_loss: 0.7618
# Epoch 14/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 36ms/step - accuracy: 0.7251 - loss: 0.7783 - val_accuracy: 0.7383 - val_loss: 0.7404
# Epoch 15/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7207 - loss: 0.7855 - val_accuracy: 0.7433 - val_loss: 0.7327
# Epoch 16/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7217 - loss: 0.7790 - val_accuracy: 0.7222 - val_loss: 0.7906
# Epoch 17/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7309 - loss: 0.7582 - val_accuracy: 0.7281 - val_loss: 0.7711
# Epoch 18/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7335 - loss: 0.7487 - val_accuracy: 0.7432 - val_loss: 0.7457
# Epoch 19/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.7434 - loss: 0.7202 - val_accuracy: 0.7414 - val_loss: 0.7353
# Epoch 20/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.7419 - loss: 0.7318 - val_accuracy: 0.7615 - val_loss: 0.6931
# Epoch 21/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.7415 - loss: 0.7196 - val_accuracy: 0.7583 - val_loss: 0.6801
# Epoch 22/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7487 - loss: 0.7043 - val_accuracy: 0.7589 - val_loss: 0.6867
# Epoch 23/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7516 - loss: 0.6953 - val_accuracy: 0.7639 - val_loss: 0.6831
# Epoch 24/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7509 - loss: 0.7022 - val_accuracy: 0.7648 - val_loss: 0.6784
# Epoch 25/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7579 - loss: 0.6881 - val_accuracy: 0.7399 - val_loss: 0.7327
# Epoch 26/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 36ms/step - accuracy: 0.7596 - loss: 0.6814 - val_accuracy: 0.7605 - val_loss: 0.6870
# Epoch 27/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7630 - loss: 0.6654 - val_accuracy: 0.7615 - val_loss: 0.6885
# Epoch 28/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.7627 - loss: 0.6739 - val_accuracy: 0.7636 - val_loss: 0.6754
# Epoch 29/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7639 - loss: 0.6657 - val_accuracy: 0.7476 - val_loss: 0.7244
# Epoch 30/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.7687 - loss: 0.6497 - val_accuracy: 0.7545 - val_loss: 0.6979
# Epoch 31/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 234s 375ms/step - accuracy: 0.7659 - loss: 0.6585 - val_accuracy: 0.7705 - val_loss: 0.6525
# Epoch 32/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 649s 1s/step - accuracy: 0.7724 - loss: 0.6436 - val_accuracy: 0.7680 - val_loss: 0.6647
# Epoch 33/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.7699 - loss: 0.6483 - val_accuracy: 0.7634 - val_loss: 0.6785
# Epoch 34/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.7789 - loss: 0.6289 - val_accuracy: 0.7812 - val_loss: 0.6451
# Epoch 35/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.7745 - loss: 0.6322 - val_accuracy: 0.7784 - val_loss: 0.6444
# Epoch 36/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.7751 - loss: 0.6335 - val_accuracy: 0.7618 - val_loss: 0.6796
# Epoch 37/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.7750 - loss: 0.6305 - val_accuracy: 0.7731 - val_loss: 0.6462
# Epoch 38/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.7791 - loss: 0.6233 - val_accuracy: 0.7549 - val_loss: 0.7143
# Epoch 39/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 126ms/step - accuracy: 0.7810 - loss: 0.6246 - val_accuracy: 0.7707 - val_loss: 0.6557
# Epoch 40/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 538s 862ms/step - accuracy: 0.7817 - loss: 0.6150 - val_accuracy: 0.7800 - val_loss: 0.6406
# Epoch 41/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 514s 823ms/step - accuracy: 0.7871 - loss: 0.6034 - val_accuracy: 0.7836 - val_loss: 0.6201
# Epoch 42/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 270s 432ms/step - accuracy: 0.7883 - loss: 0.5995 - val_accuracy: 0.7763 - val_loss: 0.6484
# Epoch 43/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 352s 564ms/step - accuracy: 0.7809 - loss: 0.6139 - val_accuracy: 0.7838 - val_loss: 0.6352
# Epoch 44/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 204s 327ms/step - accuracy: 0.7861 - loss: 0.6035 - val_accuracy: 0.7797 - val_loss: 0.6481
# Epoch 45/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 234s 375ms/step - accuracy: 0.7870 - loss: 0.6046 - val_accuracy: 0.7680 - val_loss: 0.6649
# Epoch 46/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 224s 359ms/step - accuracy: 0.7899 - loss: 0.6031 - val_accuracy: 0.7748 - val_loss: 0.6521
# Epoch 47/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 389s 623ms/step - accuracy: 0.7871 - loss: 0.5946 - val_accuracy: 0.7684 - val_loss: 0.6642
# Epoch 48/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 227s 364ms/step - accuracy: 0.7956 - loss: 0.5814 - val_accuracy: 0.7887 - val_loss: 0.6213
# Epoch 49/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 131s 210ms/step - accuracy: 0.7975 - loss: 0.5760 - val_accuracy: 0.7724 - val_loss: 0.6543
# Epoch 50/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 248s 397ms/step - accuracy: 0.7927 - loss: 0.5856 - val_accuracy: 0.7781 - val_loss: 0.6420
# Epoch 51/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 127s 204ms/step - accuracy: 0.7926 - loss: 0.5816 - val_accuracy: 0.7731 - val_loss: 0.6466
# Epoch 52/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 133s 214ms/step - accuracy: 0.7943 - loss: 0.5761 - val_accuracy: 0.7834 - val_loss: 0.6305
# Epoch 53/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 229s 367ms/step - accuracy: 0.7896 - loss: 0.5929 - val_accuracy: 0.7857 - val_loss: 0.6211
# Epoch 54/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 123s 197ms/step - accuracy: 0.7978 - loss: 0.5713 - val_accuracy: 0.7788 - val_loss: 0.6332
# Epoch 55/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 232s 371ms/step - accuracy: 0.7974 - loss: 0.5755 - val_accuracy: 0.7781 - val_loss: 0.6476
# Epoch 56/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 145s 233ms/step - accuracy: 0.7962 - loss: 0.5712 - val_accuracy: 0.7896 - val_loss: 0.6132
# Epoch 57/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 151s 241ms/step - accuracy: 0.8002 - loss: 0.5653 - val_accuracy: 0.7859 - val_loss: 0.6262
# Epoch 58/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 381s 611ms/step - accuracy: 0.7926 - loss: 0.5766 - val_accuracy: 0.7741 - val_loss: 0.6471
# Epoch 59/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 334s 535ms/step - accuracy: 0.7997 - loss: 0.5695 - val_accuracy: 0.7895 - val_loss: 0.6128
# Epoch 60/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 256s 411ms/step - accuracy: 0.7968 - loss: 0.5709 - val_accuracy: 0.7865 - val_loss: 0.6181
# Epoch 61/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 225s 361ms/step - accuracy: 0.7983 - loss: 0.5653 - val_accuracy: 0.7867 - val_loss: 0.6112
# Epoch 62/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 120ms/step - accuracy: 0.7953 - loss: 0.5739 - val_accuracy: 0.7871 - val_loss: 0.6278
# Epoch 63/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 349s 560ms/step - accuracy: 0.8008 - loss: 0.5550 - val_accuracy: 0.7930 - val_loss: 0.6042
# Epoch 64/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 350s 560ms/step - accuracy: 0.8049 - loss: 0.5508 - val_accuracy: 0.7883 - val_loss: 0.6085
# Epoch 65/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 406s 650ms/step - accuracy: 0.8026 - loss: 0.5597 - val_accuracy: 0.7793 - val_loss: 0.6447
# Epoch 66/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 418s 670ms/step - accuracy: 0.8012 - loss: 0.5630 - val_accuracy: 0.7783 - val_loss: 0.6440
# Epoch 67/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 675s 1s/step - accuracy: 0.8059 - loss: 0.5546 - val_accuracy: 0.7813 - val_loss: 0.6329
# Epoch 68/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1022s 2s/step - accuracy: 0.8032 - loss: 0.5538 - val_accuracy: 0.7843 - val_loss: 0.6218
# Epoch 69/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 426s 683ms/step - accuracy: 0.8008 - loss: 0.5595 - val_accuracy: 0.7850 - val_loss: 0.6201
# Epoch 70/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 225s 361ms/step - accuracy: 0.8081 - loss: 0.5433 - val_accuracy: 0.7977 - val_loss: 0.5911
# Epoch 71/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 956s 2s/step - accuracy: 0.8075 - loss: 0.5448 - val_accuracy: 0.7981 - val_loss: 0.5893
# Epoch 72/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 142s 228ms/step - accuracy: 0.8042 - loss: 0.5596 - val_accuracy: 0.7829 - val_loss: 0.6170
# Epoch 73/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 213s 341ms/step - accuracy: 0.8076 - loss: 0.5457 - val_accuracy: 0.7922 - val_loss: 0.6022
# Epoch 74/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 448s 717ms/step - accuracy: 0.8074 - loss: 0.5338 - val_accuracy: 0.7843 - val_loss: 0.6219
# Epoch 75/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 223s 357ms/step - accuracy: 0.8065 - loss: 0.5517 - val_accuracy: 0.7989 - val_loss: 0.5884
# Epoch 76/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 233s 373ms/step - accuracy: 0.8138 - loss: 0.5269 - val_accuracy: 0.7844 - val_loss: 0.6242
# Epoch 77/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 130s 209ms/step - accuracy: 0.8075 - loss: 0.5435 - val_accuracy: 0.7873 - val_loss: 0.6186
# Epoch 78/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 284s 454ms/step - accuracy: 0.8097 - loss: 0.5279 - val_accuracy: 0.7953 - val_loss: 0.5979
# Epoch 79/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 58s 93ms/step - accuracy: 0.8131 - loss: 0.5246 - val_accuracy: 0.7905 - val_loss: 0.6137
# Epoch 80/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 236s 379ms/step - accuracy: 0.8099 - loss: 0.5386 - val_accuracy: 0.7891 - val_loss: 0.6200
# Epoch 81/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 211s 338ms/step - accuracy: 0.8092 - loss: 0.5394 - val_accuracy: 0.7782 - val_loss: 0.6426
# Epoch 82/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 319s 511ms/step - accuracy: 0.8125 - loss: 0.5299 - val_accuracy: 0.7929 - val_loss: 0.6019
# Epoch 83/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 171s 274ms/step - accuracy: 0.8096 - loss: 0.5349 - val_accuracy: 0.7952 - val_loss: 0.5994
# Epoch 84/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 598s 958ms/step - accuracy: 0.8149 - loss: 0.5258 - val_accuracy: 0.7955 - val_loss: 0.5996
# Epoch 85/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 121s 194ms/step - accuracy: 0.8171 - loss: 0.5205 - val_accuracy: 0.7958 - val_loss: 0.5987
# Epoch 86/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 232s 372ms/step - accuracy: 0.8142 - loss: 0.5251 - val_accuracy: 0.7940 - val_loss: 0.5933
# Epoch 87/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 231s 370ms/step - accuracy: 0.8070 - loss: 0.5348 - val_accuracy: 0.7865 - val_loss: 0.6204
# Epoch 88/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 113s 181ms/step - accuracy: 0.8140 - loss: 0.5288 - val_accuracy: 0.7850 - val_loss: 0.6281
# Epoch 89/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 661s 1s/step - accuracy: 0.8138 - loss: 0.5263 - val_accuracy: 0.7906 - val_loss: 0.6060
# Epoch 90/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 628s 1s/step - accuracy: 0.8137 - loss: 0.5246 - val_accuracy: 0.7774 - val_loss: 0.6514
# Epoch 91/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 122s 196ms/step - accuracy: 0.8121 - loss: 0.5232 - val_accuracy: 0.7957 - val_loss: 0.5895
# Epoch 92/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 329s 527ms/step - accuracy: 0.8164 - loss: 0.5172 - val_accuracy: 0.7857 - val_loss: 0.6185
# Epoch 93/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 127s 204ms/step - accuracy: 0.8172 - loss: 0.5117 - val_accuracy: 0.7998 - val_loss: 0.5869
# Epoch 94/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 780s 1s/step - accuracy: 0.8178 - loss: 0.5160 - val_accuracy: 0.7967 - val_loss: 0.5872
# Epoch 95/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 231s 370ms/step - accuracy: 0.8222 - loss: 0.5071 - val_accuracy: 0.7956 - val_loss: 0.5903
# Epoch 96/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 149s 239ms/step - accuracy: 0.8176 - loss: 0.5138 - val_accuracy: 0.8062 - val_loss: 0.5749
# Epoch 97/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 231s 371ms/step - accuracy: 0.8184 - loss: 0.5069 - val_accuracy: 0.8005 - val_loss: 0.5784
# Epoch 98/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 400s 641ms/step - accuracy: 0.8180 - loss: 0.5061 - val_accuracy: 0.7966 - val_loss: 0.6018
# Epoch 99/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 683s 1s/step - accuracy: 0.8101 - loss: 0.5287 - val_accuracy: 0.7958 - val_loss: 0.6072
# Epoch 100/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1059s 2s/step - accuracy: 0.8161 - loss: 0.5140 - val_accuracy: 0.7940 - val_loss: 0.5949

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 2s - 6ms/step - accuracy: 0.7855 - loss: 0.6249

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()

# %%
#for idx, model in enumerate(model_list):
#    model.save(f'model_{idx}.h5')
get_flops(model, train_images.shape)
# Out:
# WARNING:tensorflow:From /Users/amiruladlilhakim/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/tensorflow/python/ops/nn_ops.py:5256: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730100766.058297  736151 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730100766.058363  736151 single_machine.cc:361] Starting new session
# 738483040000
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   731.38b float_ops (100.00%, 99.04%)
# MatMul                   2.67b float_ops (0.96%, 0.36%)
# AddV2                    2.21b float_ops (0.60%, 0.30%)
# MaxPool                  2.21b float_ops (0.30%, 0.30%)
# Softmax                  2.00m float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================

# %%
def get_layer(model, layer_index):
    return [layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)][layer_index]

def get_filters(model, layer_index, filter_indices):
    layer = get_layer(model, layer_index)
    filters, biases = layer.get_weights()
    return filters[:, :, :, filter_indices]

# %%
'''def norms(model_index, layer_index, model_list):    
    model_norm_list = []
    for model_idx, model in enumerate(model_list):
        #print(model_idx)
        layer_norm_list = []
        for layer_idx, layer in enumerate([layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)]):
            #print(layer_idx)
            norm_list = []
            filters, biases = layer.get_weights()
            num_filters = filters.shape[-1]
            for i in range(num_filters):
                
                filt = filters[:, :, :, i]
                filt_matrix = filt.reshape(-1, filt.shape[-1])
                norm = np.linalg.norm(filt_matrix)
                norm_list.append(norm)
            layer_norm_list.append(norm_list)
        model_norm_list.append(layer_norm_list)
    return model_norm_list[model_index][layer_index]'''

def get_norm(model, layer_name):
    layer = model.get_layer(layer_name)
    filters, biases = layer.get_weights()
    num_filters = filters.shape[-1]
    norms = []
    for i in range(num_filters):
        filt = filters[:, :, :, i]
        filt_matrix = filt.reshape(-1, filt.shape[-1])
        norm = np.linalg.norm(filt_matrix)
        norms.append(norm)
    return norms

norm_conv2 = get_norm(model, 'conv2')
norm_conv3 = get_norm(model, 'conv3')
norm_conv4 = get_norm(model, 'conv4')

# %%
def filter_to_zero(norms, percentage):
    threshold = np.percentile(norms, percentage)
    return [i for i, norm in enumerate(norms) if norm < threshold]

def filter_to_keep(norms, percentage):
    threshold = np.percentile(norms, percentage)
    return [i for i, norm in enumerate(norms) if norm >= threshold]

# %% [markdown]
# Set insignificant filters elements to 0, doesnt reduce FLOPS XD

# %%
'''for model_idx, model in enumerate(model_list):
    for layer_idx, layer in enumerate([layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)]):
        w, b = layer.get_weights()
        w[:, :, :, filter_to_zero(norms(model_idx, layer_idx, model_list), 85)] = 0
        b[filter_to_zero(norms(model_idx, layer_idx, model_list), 85)] = 0
        layer.set_weights([w, b])'''
# Out:
# 'for model_idx, model in enumerate(model_list):\n    for layer_idx, layer in enumerate([layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)]):\n        w, b = layer.get_weights()\n        w[:, :, :, filter_to_zero(norms(model_idx, layer_idx, model_list), 85)] = 0\n        b[filter_to_zero(norms(model_idx, layer_idx, model_list), 85)] = 0\n        layer.set_weights([w, b])'

# %% [markdown]
# Try to remove some entirely the insignificant filters

# %%
keep_filt_conv2 = filter_to_keep(norm_conv2, 90)
keep_filt_conv3 = filter_to_keep(norm_conv3, 60)
keep_filt_conv4 = filter_to_keep(norm_conv4, 90)

# %%
keep_filt_conv3
# Out:
# [0,
#  3,
#  4,
#  7,
#  9,
#  10,
#  17,
#  19,
#  20,
#  21,
#  22,
#  25,
#  27,
#  32,
#  33,
#  38,
#  40,
#  48,
#  49,
#  51,
#  55,
#  58,
#  59,
#  60,
#  61,
#  62]

# %%
'''pruned_target_model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=X.shape[1:], name='target_conv1'),
        MaxPooling2D((2,2), name='target_pool1'),
        Conv2D(len(keep_filt), (3,3), activation='relu', name='target_conv2'),
        MaxPooling2D((2,2), name='target_pool2'),
        Flatten(name='target_flatten'),
        Dense(len(keep_filt), activation='relu', name='target_fc1'),
        Dense(10, activation='softmax', name='target_output')
        ])'''

pruned_target_model = Sequential([
        Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3), name='conv1'),
        MaxPooling2D((2,2), name='pool1'),
        Dropout(0.25),
        Conv2D(64, (3,3), activation='relu', padding='same', name='conv2'),
        MaxPooling2D((2,2), name='pool2'),
        Dropout(0.25),
        Conv2D(len(keep_filt_conv3), (3,3), activation='relu', padding='same',  name='conv3'),
        MaxPooling2D((2,2), name='pool3'),
        Dropout(0.25),
        Conv2D(len(keep_filt_conv4), (3,3), activation='relu', padding='same',  name='conv4'),
        MaxPooling2D((2,2), name='pool4'),
        Dropout(0.25),
        #Conv2D(128, (3,3), activation='relu', padding='same', name='conv5'),
        Flatten(name='flatten'),
        Dense(len(keep_filt_conv4), activation='relu', name='fc1'),
        Dense(10, activation='softmax', name='output')
        ])

# %%
pruned_target_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1 (Conv2D)                  │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool1 (MaxPooling2D)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool2 (MaxPooling2D)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 8, 8, 26)       │        15,002 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool3 (MaxPooling2D)            │ (None, 4, 4, 26)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 4, 26)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4 (Conv2D)                  │ (None, 4, 4, 13)       │         3,055 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool4 (MaxPooling2D)            │ (None, 2, 2, 13)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 2, 2, 13)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 52)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 13)             │           689 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │           140 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,278 (149.52 KB)
#  Trainable params: 38,278 (149.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
'''def copy_weights_pruned(source_model, pruned_target_model, source_layer_name, target_layer_name):
    for source_layer, target_layer in zip(source_model.layers, pruned_target_model.layers):
        if isinstance(source_layer, tf.keras.layers.Conv2D) and source_layer.name != source_layer_name and target_layer.name != target_layer_name:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w, b])
        elif source_layer.name == source_layer_name and target_layer.name == target_layer_name:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w[:, :, :, keep_filt], b[keep_filt]])'''
def get_var_name(var):
    for name, value in locals().items():
        if value is var:
            return name

def copy_weights_pruned(source_model, pruned_target_model, source_layer_names, target_layer_names, keep_filters):
    for source_layer, target_layer in zip(source_model.layers, pruned_target_model.layers):
        if isinstance(source_layer, tf.keras.layers.Conv2D) and source_layer.name not in source_layer_names and target_layer.name not in target_layer_names:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w, b])
        elif source_layer.name in source_layer_names and target_layer.name in target_layer_names:
            for keep_filt in keep_filters:
                if source_layer.name in get_var_name(keep_filt):
                    w, b = source_layer.get_weights()
                    target_layer.set_weights([w[:, :, :, keep_filt], b[keep_filt]])

# %%
copy_weights_pruned(model, pruned_target_model, [ 'conv3', 'conv4'], [ 'conv3', 'conv4'], [ keep_filt_conv3, keep_filt_conv4])

# %%
pruned_target_model.get_layer('conv3').get_weights()[0].shape
# Out:
# (3, 3, 64, 26)

# %%
pruned_target_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = pruned_target_model.fit(train_images, train_labels, epochs=100, batch_size=64, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 994s 2s/step - accuracy: 0.2557 - loss: 1.9749 - val_accuracy: 0.5430 - val_loss: 1.2990
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 387s 620ms/step - accuracy: 0.5159 - loss: 1.3311 - val_accuracy: 0.6194 - val_loss: 1.0946
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 573s 918ms/step - accuracy: 0.5730 - loss: 1.1954 - val_accuracy: 0.6566 - val_loss: 0.9875
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 874s 1s/step - accuracy: 0.5925 - loss: 1.1311 - val_accuracy: 0.6621 - val_loss: 0.9581
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 69s 111ms/step - accuracy: 0.6043 - loss: 1.0870 - val_accuracy: 0.6735 - val_loss: 0.9322
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 538s 863ms/step - accuracy: 0.6225 - loss: 1.0499 - val_accuracy: 0.6829 - val_loss: 0.9063
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 264s 423ms/step - accuracy: 0.6304 - loss: 1.0340 - val_accuracy: 0.6817 - val_loss: 0.9019
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 355s 569ms/step - accuracy: 0.6372 - loss: 1.0182 - val_accuracy: 0.7075 - val_loss: 0.8531
# Epoch 9/100
# 339/625 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - accuracy: 0.6444 - loss: 1.0046
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 pruned_target_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# ----> 2 history = pruned_target_model.fit(train_images, train_labels, epochs=100, batch_size=64, validation_data=(val_images, val_labels))
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File ~/Documents/VirtualEnv/tensorflow_env/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
test_loss, test_acc = pruned_target_model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 2s - 5ms/step - accuracy: 0.7138 - loss: 0.8522

# %%
get_flops(pruned_target_model, train_images.shape)
# Out:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
# I0000 00:00:1730072673.866395  505164 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# I0000 00:00:1730072673.866476  505164 single_machine.cc:361] Starting new session
# 397159516800
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   394.15b float_ops (100.00%, 99.24%)
# AddV2                    1.48b float_ops (0.76%, 0.37%)
# MaxPool                  1.48b float_ops (0.38%, 0.37%)
# MatMul                   46.43m float_ops (0.01%, 0.01%)
# Softmax                  1.44m float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()

# %%
model.save('model.h5')
pruned_target_model.save('pruned_target_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
