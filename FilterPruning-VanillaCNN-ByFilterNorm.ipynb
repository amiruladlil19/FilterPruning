# %%
import tensorflow as tf
import numpy as np
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import clone_model
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from numpy.random import default_rng
from tensorflow.keras.models import load_model
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
# Out:
# 2024-10-29 18:05:22.472013: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-29 18:05:22.497126: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-29 18:05:22.497154: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-29 18:05:22.497908: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-29 18:05:22.502103: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-29 18:05:23.003066: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
plt.imshow(train_images[0])

# %%
num_classes = 10
train_labels = to_categorical(train_labels, num_classes)
test_labels = to_categorical(test_labels, num_classes)

# %%
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

# %%
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.flatten()

for img, lbl, ax in zip(train_images, train_labels, axes):
    ax.imshow(img)
    ax.set_title(f'Label: {lbl}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
'''model_list = []

for i in range(10):
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3), name='conv1'),
        MaxPooling2D((2,2), name='pool1'),
        Conv2D(64, (3,3), activation='relu', name='conv2'),
        MaxPooling2D((2,2), name='pool2'),
        Conv2D(64, (3,3), activation='relu', name='conv3'),
        Flatten(name='flatten'),
        Dense(64, activation='relu', name='fc1'),
        Dense(10, activation='softmax', name='output')
        ])
    model_list.append(model)'''
model = Sequential([
        Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3), name='conv1'),
        Conv2D(32, (3,3), activation='relu', padding='same', name='conv2'),
        MaxPooling2D((2,2), name='pool1'),
        Dropout(0.25),

        Conv2D(64, (3,3), activation='relu', padding='same', name='conv3'),
        Conv2D(64, (3,3), activation='relu', padding='same',  name='conv4'),
        MaxPooling2D((2,2), name='pool2'),
        Dropout(0.25),

        Conv2D(128, (3,3), activation='relu', padding='same',  name='conv5'),
        Conv2D(128, (3,3), activation='relu', padding='same',  name='conv6'),
        MaxPooling2D((2,2), name='pool3'),
        Dropout(0.25),

        Conv2D(256, (3,3), activation='relu', padding='same',  name='conv7'),
        MaxPooling2D((2,2), name='pool4'),
        Dropout(0.25),
        #Conv2D(128, (3,3), activation='relu', padding='same', name='conv5'),
        Flatten(name='flatten'),
        Dense(128, activation='relu', name='fc1'),
        Dense(64, activation='relu', name='fc2'),
        Dense(10, activation='softmax', name='output')
        ])
# Out:
# 2024-10-29 18:05:31.087538: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:05:31.129616: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:05:31.129742: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:05:31.131120: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:05:31.131226: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:05:31.131310: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:05:31.184563: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:05:31.184679: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:05:31.184737: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:236] Using CUDA malloc Async allocator for GPU: 0
# 2024-10-29 18:05:31.184818: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:05:31.184880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7629 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  conv7 (Conv2D)              (None, 4, 4, 256)         295168
#
#  pool4 (MaxPooling2D)        (None, 2, 2, 256)         0
#
#  dropout_3 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  fc1 (Dense)                 (None, 128)               131200
#
#  fc2 (Dense)                 (None, 64)                8256
#
#  output (Dense)              (None, 10)                650
#
# =================================================================
# Total params: 722282 (2.76 MB)
# Trainable params: 722282 (2.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def get_flops(model, input_shape):
    # Create a concrete function from the Keras model
    @tf.function
    def model_func(x):
        return model(x)
    
    # Get the concrete function
    concrete_func = model_func.get_concrete_function(tf.TensorSpec(input_shape, model.inputs[0].dtype))
    
    # Convert variables to constants and get the frozen graph
    frozen_func = convert_variables_to_constants_v2(concrete_func)
    frozen_graph = frozen_func.graph.as_graph_def()
    
    # Use TensorFlow's profiler
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(frozen_graph, name='')
        run_meta = tf.compat.v1.RunMetadata()
        with tf.compat.v1.Session(graph=graph) as sess:
            flops = tf.compat.v1.profiler.profile(
                graph=graph,
                run_meta=run_meta,
                cmd='op',
                options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
            )
            return flops.total_float_ops

# %%
'''for i in model_list:
    i.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    i.fit(X, y_one_hot, epochs=100, batch_size=2)
    loss_list.append(i.evaluate(X, y_one_hot)[0])
    accuracy_list.append(i.evaluate(X, y_one_hot)[1])'''
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, epochs=100, batch_size=64, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/100
# 2024-10-29 18:05:49.349181: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-10-29 18:05:49.474255: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-10-29 18:05:50.248171: I external/local_xla/xla/service/service.cc:168] XLA service 0x712136c09020 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-29 18:05:50.248187: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2024-10-29 18:05:50.252348: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730192750.303395 1301621 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 625/625 [==============================] - 9s 8ms/step - loss: 1.8184 - accuracy: 0.3044 - val_loss: 1.5010 - val_accuracy: 0.4312
# Epoch 2/100
# 625/625 [==============================] - 5s 8ms/step - loss: 1.3787 - accuracy: 0.4911 - val_loss: 1.2424 - val_accuracy: 0.5460
# Epoch 3/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.1478 - accuracy: 0.5849 - val_loss: 1.0124 - val_accuracy: 0.6361
# Epoch 4/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.0241 - accuracy: 0.6324 - val_loss: 0.9519 - val_accuracy: 0.6619
# Epoch 5/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.9284 - accuracy: 0.6678 - val_loss: 0.8670 - val_accuracy: 0.6904
# Epoch 6/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.8523 - accuracy: 0.6978 - val_loss: 0.7786 - val_accuracy: 0.7302
# Epoch 7/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7932 - accuracy: 0.7200 - val_loss: 0.7657 - val_accuracy: 0.7310
# Epoch 8/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7489 - accuracy: 0.7340 - val_loss: 0.7629 - val_accuracy: 0.7359
# Epoch 9/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7110 - accuracy: 0.7511 - val_loss: 0.7022 - val_accuracy: 0.7579
# Epoch 10/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.6778 - accuracy: 0.7606 - val_loss: 0.6659 - val_accuracy: 0.7704
# Epoch 11/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.6517 - accuracy: 0.7698 - val_loss: 0.6646 - val_accuracy: 0.7721
# Epoch 12/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.6235 - accuracy: 0.7811 - val_loss: 0.6431 - val_accuracy: 0.7808
# Epoch 13/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.6036 - accuracy: 0.7876 - val_loss: 0.6382 - val_accuracy: 0.7776
# Epoch 14/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.5916 - accuracy: 0.7895 - val_loss: 0.6092 - val_accuracy: 0.7931
# Epoch 15/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.5702 - accuracy: 0.7987 - val_loss: 0.6129 - val_accuracy: 0.7919
# Epoch 16/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5554 - accuracy: 0.8055 - val_loss: 0.6408 - val_accuracy: 0.7861
# Epoch 17/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.5414 - accuracy: 0.8102 - val_loss: 0.5886 - val_accuracy: 0.7966
# Epoch 18/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5230 - accuracy: 0.8168 - val_loss: 0.6103 - val_accuracy: 0.7918
# Epoch 19/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5117 - accuracy: 0.8209 - val_loss: 0.5921 - val_accuracy: 0.7989
# Epoch 20/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4980 - accuracy: 0.8274 - val_loss: 0.5830 - val_accuracy: 0.8013
# Epoch 21/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.
100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2517 - accuracy: 0.9134 - val_loss: 0.6316 - val_accuracy: 0.8135
# Epoch 82/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2527 - accuracy: 0.9143 - val_loss: 0.5766 - val_accuracy: 0.8277
# Epoch 83/100
# 625/625 [==============================] - 6s 9ms/step - loss: 0.2490 - accuracy: 0.9147 - val_loss: 0.6256 - val_accuracy: 0.8269
# Epoch 84/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2556 - accuracy: 0.9125 - val_loss: 0.5697 - val_accuracy: 0.8309
# Epoch 85/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2412 - accuracy: 0.9169 - val_loss: 0.5621 - val_accuracy: 0.8343
# Epoch 86/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2441 - accuracy: 0.9177 - val_loss: 0.5703 - val_accuracy: 0.8336
# Epoch 87/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2445 - accuracy: 0.9167 - val_loss: 0.5648 - val_accuracy: 0.8294
# Epoch 88/100
# 625/625 [==============================] - 6s 9ms/step - loss: 0.2499 - accuracy: 0.9152 - val_loss: 0.5765 - val_accuracy: 0.8333
# Epoch 89/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2384 - accuracy: 0.9186 - val_loss: 0.5545 - val_accuracy: 0.8359
# Epoch 90/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2430 - accuracy: 0.9189 - val_loss: 0.5372 - val_accuracy: 0.8399
# Epoch 91/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2380 - accuracy: 0.9189 - val_loss: 0.5738 - val_accuracy: 0.8326
# Epoch 92/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2398 - accuracy: 0.9190 - val_loss: 0.5594 - val_accuracy: 0.8358
# Epoch 93/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2382 - accuracy: 0.9188 - val_loss: 0.5487 - val_accuracy: 0.8366
# Epoch 94/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2301 - accuracy: 0.9233 - val_loss: 0.5592 - val_accuracy: 0.8325
# Epoch 95/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2383 - accuracy: 0.9200 - val_loss: 0.5834 - val_accuracy: 0.8333
# Epoch 96/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2364 - accuracy: 0.9205 - val_loss: 0.5916 - val_accuracy: 0.8326
# Epoch 97/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2334 - accuracy: 0.9213 - val_loss: 0.5715 - val_accuracy: 0.8404
# Epoch 98/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2329 - accuracy: 0.9220 - val_loss: 0.5949 - val_accuracy: 0.8304
# Epoch 99/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2314 - accuracy: 0.9216 - val_loss: 0.5711 - val_accuracy: 0.8341
# Epoch 100/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2313 - accuracy: 0.9231 - val_loss: 0.5959 - val_accuracy: 0.8297

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.6192 - accuracy: 0.8252 - 690ms/epoch - 2ms/step

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()

# %%
#for idx, model in enumerate(model_list):
#    model.save(f'model_{idx}.h5')
get_flops(model, train_images.shape)
# Out:
# 2024-10-29 18:13:39.047120: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.047428: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-10-29 18:13:39.047471: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-10-29 18:13:39.047667: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.047757: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.047831: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.047933: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.048012: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.048064: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7629 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# WARNING:tensorflow:From /home/am/Documents/VirtualEnv/tensorflow-gpu/lib/python3.11/site-packages/tensorflow/python/ops/nn_ops.py:5256: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
#
# =========================Options=============================
# 2024-10-29 18:13:39.273753: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.273939: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.274028: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.274141: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.274333: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:13:39.274409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7629 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 3486576480000
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   3468.17b float_ops (100.00%, 99.47%)
# MatMul                   11.19b float_ops (0.53%, 0.32%)
# BiasAdd                  4.76b float_ops (0.21%, 0.14%)
# MaxPool                  2.46b float_ops (0.07%, 0.07%)
# Softmax                  2.00m float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================

# %%
def get_layer(model, layer_index):
    return [layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)][layer_index]

def get_filters(model, layer_index, filter_indices):
    layer = get_layer(model, layer_index)
    filters, biases = layer.get_weights()
    return filters[:, :, :, filter_indices]

def get_all_filters(model, layer_name):
    layer = model.get_layer(name=layer_name)
    filters, biases = layer.get_weights()
    return filters

# %%
get_all_filters(model, 'conv1').shape
# Out:
# (3, 3, 3, 32)

# %%
'''def norms(model_index, layer_index, model_list):    
    model_norm_list = []
    for model_idx, model in enumerate(model_list):
        #print(model_idx)
        layer_norm_list = []
        for layer_idx, layer in enumerate([layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)]):
            #print(layer_idx)
            norm_list = []
            filters, biases = layer.get_weights()
            num_filters = filters.shape[-1]
            for i in range(num_filters):
                
                filt = filters[:, :, :, i]
                filt_matrix = filt.reshape(-1, filt.shape[-1])
                norm = np.linalg.norm(filt_matrix)
                norm_list.append(norm)
            layer_norm_list.append(norm_list)
        model_norm_list.append(layer_norm_list)
    return model_norm_list[model_index][layer_index]'''

def get_norm(model, layer_name):
    layer = model.get_layer(layer_name)
    filters, biases = layer.get_weights()
    num_filters = filters.shape[-1]
    norms = []
    for i in range(num_filters):
        filt = filters[:, :, :, i]
        filt_matrix = filt.reshape(-1, filt.shape[-1])
        norm = np.linalg.norm(filt_matrix)
        norms.append(norm)
    return norms

'''def get_filter_uniqueness(model, layer_name):
    layer = model.get_layer(layer_name)
    filters, biases = layer.get_weights()
    num_filters = filters.shape[-1]
    uniqueness_list = []
    for i in range(num_filters):
        filt = filters[:, :, :, i]
        filt_matrix = filt.reshape(-1, filt.shape[-1])
        uniqueness = np.linalg.norm(filt_matrix) - np.linalg.norm(get_all_filters(model, layer_name))

        uniqueness_list.append(uniqueness)
    return uniqueness_list'''

norm_conv3 = get_norm(model, 'conv3')
norm_conv4 = get_norm(model, 'conv4')
norm_conv5 = get_norm(model, 'conv5')
norm_conv6 = get_norm(model, 'conv6')
norm_conv7 = get_norm(model, 'conv7')

# %%
def filter_to_zero(norms, percentage):
    threshold = np.percentile(norms, percentage)
    return [i for i, norm in enumerate(norms) if norm < threshold]

def filter_to_keep(norms, percentage):
    threshold = np.percentile(norms, percentage)
    return [i for i, norm in enumerate(norms) if norm >= threshold]

# %%
keep_filt_conv3 = filter_to_keep(norm_conv3, 50)
keep_filt_conv4 = filter_to_keep(norm_conv4, 50)
keep_filt_conv5 = filter_to_keep(norm_conv5, 70)
keep_filt_conv6 = filter_to_keep(norm_conv6, 70)
keep_filt_conv7 = filter_to_keep(norm_conv7, 90)

# %%
'''pruned_target_model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=X.shape[1:], name='target_conv1'),
        MaxPooling2D((2,2), name='target_pool1'),
        Conv2D(len(keep_filt), (3,3), activation='relu', name='target_conv2'),
        MaxPooling2D((2,2), name='target_pool2'),
        Flatten(name='target_flatten'),
        Dense(len(keep_filt), activation='relu', name='target_fc1'),
        Dense(10, activation='softmax', name='target_output')
        ])'''

pruned_target_model = Sequential([
        Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3), name='conv1'),
        Conv2D(32, (3,3), activation='relu', padding='same', name='conv2'),
        MaxPooling2D((2,2), name='pool1'),
        Dropout(0.25),

        Conv2D(len(keep_filt_conv3), (3,3), activation='relu', padding='same', name='conv3'),
        Conv2D(len(keep_filt_conv4), (3,3), activation='relu', padding='same',  name='conv4'),
        MaxPooling2D((2,2), name='pool2'),
        Dropout(0.25),

        Conv2D(len(keep_filt_conv5), (3,3), activation='relu', padding='same',  name='conv5'),
        Conv2D(len(keep_filt_conv6), (3,3), activation='relu', padding='same',  name='conv6'),
        MaxPooling2D((2,2), name='pool3'),
        Dropout(0.25),

        Conv2D(len(keep_filt_conv7), (3,3), activation='relu', padding='same',  name='conv7'),
        MaxPooling2D((2,2), name='pool4'),
        Dropout(0.25),
        #Conv2D(128, (3,3), activation='relu', padding='same', name='conv5'),
        Flatten(name='flatten'),
        Dense(len(keep_filt_conv7), activation='relu', name='fc1'),
        Dense(64, activation='relu', name='fc2'),
        Dense(10, activation='softmax', name='output')
        ])

# %%
pruned_target_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  dropout_4 (Dropout)         (None, 16, 16, 32)        0
#
#  conv3 (Conv2D)              (None, 16, 16, 32)        9248
#
#  conv4 (Conv2D)              (None, 16, 16, 32)        9248
#
#  pool2 (MaxPooling2D)        (None, 8, 8, 32)          0
#
#  dropout_5 (Dropout)         (None, 8, 8, 32)          0
#
#  conv5 (Conv2D)              (None, 8, 8, 39)          11271
#
#  conv6 (Conv2D)              (None, 8, 8, 39)          13728
#
#  pool3 (MaxPooling2D)        (None, 4, 4, 39)          0
#
#  dropout_6 (Dropout)         (None, 4, 4, 39)          0
#
#  conv7 (Conv2D)              (None, 4, 4, 26)          9152
#
#  pool4 (MaxPooling2D)        (None, 2, 2, 26)          0
#
#  dropout_7 (Dropout)         (None, 2, 2, 26)          0
#
#  flatten (Flatten)           (None, 104)               0
#
#  fc1 (Dense)                 (None, 26)                2730
#
#  fc2 (Dense)                 (None, 64)                1728
#
#  output (Dense)              (None, 10)                650
#
# =================================================================
# Total params: 67899 (265.23 KB)
# Trainable params: 67899 (265.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
'''def copy_weights_pruned(source_model, pruned_target_model, source_layer_name, target_layer_name):
    for source_layer, target_layer in zip(source_model.layers, pruned_target_model.layers):
        if isinstance(source_layer, tf.keras.layers.Conv2D) and source_layer.name != source_layer_name and target_layer.name != target_layer_name:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w, b])
        elif source_layer.name == source_layer_name and target_layer.name == target_layer_name:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w[:, :, :, keep_filt], b[keep_filt]])'''
def get_var_name(var):
    for name, value in locals().items():
        if value is var:
            return name

def copy_weights_pruned(source_model, pruned_target_model, source_layer_names, target_layer_names, keep_filters):
    for source_layer, target_layer in zip(source_model.layers, pruned_target_model.layers):
        if isinstance(source_layer, tf.keras.layers.Conv2D) and source_layer.name not in source_layer_names and target_layer.name not in target_layer_names:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w, b])
        elif source_layer.name in source_layer_names and target_layer.name in target_layer_names:
            for keep_filt in keep_filters:
                if source_layer.name in get_var_name(keep_filt):
                    w, b = source_layer.get_weights()
                    target_layer.set_weights([w[:, :, :, keep_filt], b[keep_filt]])

# %%
copy_weights_pruned(model, pruned_target_model, [ 'conv3', 'conv4', 'conv5', 'conv6', 'conv7'], [ 'conv3', 'conv4', 'conv5', 'conv6', 'conv7'], [ keep_filt_conv3, keep_filt_conv4, keep_filt_conv5, keep_filt_conv6, keep_filt_conv7])

# %%
pruned_target_model.get_layer('conv3').get_weights()[0].shape
# Out:
# (3, 3, 32, 32)

# %%
pruned_target_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = pruned_target_model.fit(train_images, train_labels, epochs=100, batch_size=64, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/100
# 2024-10-29 18:13:41.488865: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout_4/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 625/625 [==============================] - 6s 7ms/step - loss: 1.7209 - accuracy: 0.3313 - val_loss: 1.3015 - val_accuracy: 0.5179
# Epoch 2/100
# 625/625 [==============================] - 4s 6ms/step - loss: 1.2593 - accuracy: 0.5366 - val_loss: 1.0558 - val_accuracy: 0.6192
# Epoch 3/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.0846 - accuracy: 0.6127 - val_loss: 0.9105 - val_accuracy: 0.6610
# Epoch 4/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.9994 - accuracy: 0.6413 - val_loss: 0.8899 - val_accuracy: 0.6812
# Epoch 5/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.9436 - accuracy: 0.6643 - val_loss: 0.8275 - val_accuracy: 0.7043
# Epoch 6/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.8979 - accuracy: 0.6822 - val_loss: 0.8172 - val_accuracy: 0.7149
# Epoch 7/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.8635 - accuracy: 0.6939 - val_loss: 0.7671 - val_accuracy: 0.7253
# Epoch 8/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.8389 - accuracy: 0.7032 - val_loss: 0.7588 - val_accuracy: 0.7241
# Epoch 9/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.8148 - accuracy: 0.7135 - val_loss: 0.7606 - val_accuracy: 0.7302
# Epoch 10/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7896 - accuracy: 0.7212 - val_loss: 0.7181 - val_accuracy: 0.7468
# Epoch 11/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7814 - accuracy: 0.7279 - val_loss: 0.7409 - val_accuracy: 0.7345
# Epoch 12/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.7616 - accuracy: 0.7346 - val_loss: 0.7088 - val_accuracy: 0.7510
# Epoch 13/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7493 - accuracy: 0.7380 - val_loss: 0.6977 - val_accuracy: 0.7542
# Epoch 14/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7330 - accuracy: 0.7437 - val_loss: 0.6722 - val_accuracy: 0.7656
# Epoch 15/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7233 - accuracy: 0.7492 - val_loss: 0.6518 - val_accuracy: 0.7710
# Epoch 16/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7195 - accuracy: 0.7497 - val_loss: 0.6968 - val_accuracy: 0.7571
# Epoch 17/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7136 - accuracy: 0.7505 - val_loss: 0.6507 - val_accuracy: 0.7709
# Epoch 18/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.7019 - accuracy: 0.7544 - val_loss: 0.7007 - val_accuracy: 0.7631
# Epoch 19/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.6961 - accuracy: 0.7571 - val_loss: 0.6431 - val_accuracy: 0.7806
# Epoch 20/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.6892 - accuracy: 0.7581 - val_loss: 0.6410 - val_accuracy: 0.7760
# Epoch 21/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6803 - accuracy: 0.7627 - val_loss: 0.6885 - val_accuracy: 0.7625
# Epoch 22/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0
100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5342 - accuracy: 0.8154 - val_loss: 0.5783 - val_accuracy: 0.8053
# Epoch 82/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5314 - accuracy: 0.8153 - val_loss: 0.5532 - val_accuracy: 0.8112
# Epoch 83/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5321 - accuracy: 0.8162 - val_loss: 0.5875 - val_accuracy: 0.7982
# Epoch 84/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5283 - accuracy: 0.8166 - val_loss: 0.5538 - val_accuracy: 0.8129
# Epoch 85/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5302 - accuracy: 0.8179 - val_loss: 0.5514 - val_accuracy: 0.8151
# Epoch 86/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5302 - accuracy: 0.8181 - val_loss: 0.5569 - val_accuracy: 0.8109
# Epoch 87/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5302 - accuracy: 0.8152 - val_loss: 0.5515 - val_accuracy: 0.8127
# Epoch 88/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5298 - accuracy: 0.8178 - val_loss: 0.5835 - val_accuracy: 0.8081
# Epoch 89/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5191 - accuracy: 0.8214 - val_loss: 0.5609 - val_accuracy: 0.8054
# Epoch 90/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5201 - accuracy: 0.8199 - val_loss: 0.5626 - val_accuracy: 0.8095
# Epoch 91/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5245 - accuracy: 0.8208 - val_loss: 0.5362 - val_accuracy: 0.8202
# Epoch 92/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5230 - accuracy: 0.8213 - val_loss: 0.5527 - val_accuracy: 0.8109
# Epoch 93/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5229 - accuracy: 0.8197 - val_loss: 0.5508 - val_accuracy: 0.8116
# Epoch 94/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5194 - accuracy: 0.8216 - val_loss: 0.5998 - val_accuracy: 0.8021
# Epoch 95/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5176 - accuracy: 0.8211 - val_loss: 0.5654 - val_accuracy: 0.8100
# Epoch 96/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5153 - accuracy: 0.8227 - val_loss: 0.5419 - val_accuracy: 0.8143
# Epoch 97/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5135 - accuracy: 0.8224 - val_loss: 0.5456 - val_accuracy: 0.8160
# Epoch 98/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5177 - accuracy: 0.8191 - val_loss: 0.5916 - val_accuracy: 0.8057
# Epoch 99/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5213 - accuracy: 0.8198 - val_loss: 0.5580 - val_accuracy: 0.8094
# Epoch 100/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5188 - accuracy: 0.8208 - val_loss: 0.5456 - val_accuracy: 0.8149

# %%
test_loss, test_acc = pruned_target_model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 0s - loss: 0.5766 - accuracy: 0.8070 - 419ms/epoch - 1ms/step

# %%
get_flops(pruned_target_model, train_images.shape)
# Out:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
# 2024-10-29 18:20:11.560533: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.560628: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-10-29 18:20:11.560689: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-10-29 18:20:11.560894: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.561026: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.561105: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.561215: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.561296: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.561350: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7629 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-10-29 18:20:11.639240: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.639388: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.639467: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.639580: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.639661: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 18:20:11.639715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7629 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 1348172400000
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   1342.52b float_ops (100.00%, 99.58%)
# BiasAdd                  3.50b float_ops (0.42%, 0.26%)
# MaxPool                  1.75b float_ops (0.16%, 0.13%)
# MatMul                   400.64m float_ops (0.03%, 0.03%)
# Softmax                  2.00m float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()

# %%
model.save('model.h5')
pruned_target_model.save('pruned_target_model.h5')
