# %%
import tensorflow as tf
import numpy as np
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import clone_model
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from numpy.random import default_rng
from tensorflow.keras.models import load_model
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
# Out:
# 2024-10-29 20:22:49.725209: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-29 20:22:49.751121: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-29 20:22:49.751156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-29 20:22:49.751865: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-29 20:22:49.756540: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-29 20:22:50.267473: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
plt.imshow(train_images[0])

# %%
num_classes = 10
train_labels = to_categorical(train_labels, num_classes)
test_labels = to_categorical(test_labels, num_classes)

# %%
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

# %%
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.flatten()

for img, lbl, ax in zip(train_images, train_labels, axes):
    ax.imshow(img)
    ax.set_title(f'Label: {lbl}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
'''model_list = []

for i in range(10):
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3), name='conv1'),
        MaxPooling2D((2,2), name='pool1'),
        Conv2D(64, (3,3), activation='relu', name='conv2'),
        MaxPooling2D((2,2), name='pool2'),
        Conv2D(64, (3,3), activation='relu', name='conv3'),
        Flatten(name='flatten'),
        Dense(64, activation='relu', name='fc1'),
        Dense(10, activation='softmax', name='output')
        ])
    model_list.append(model)'''
model = Sequential([
        Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3), name='conv1'),
        Conv2D(32, (3,3), activation='relu', padding='same', name='conv2'),
        MaxPooling2D((2,2), name='pool1'),
        Dropout(0.25),

        Conv2D(64, (3,3), activation='relu', padding='same', name='conv3'),
        Conv2D(64, (3,3), activation='relu', padding='same',  name='conv4'),
        MaxPooling2D((2,2), name='pool2'),
        Dropout(0.25),

        Conv2D(128, (3,3), activation='relu', padding='same',  name='conv5'),
        Conv2D(128, (3,3), activation='relu', padding='same',  name='conv6'),
        MaxPooling2D((2,2), name='pool3'),
        Dropout(0.25),

        Conv2D(256, (3,3), activation='relu', padding='same',  name='conv7'),
        MaxPooling2D((2,2), name='pool4'),
        Dropout(0.25),
        #Conv2D(128, (3,3), activation='relu', padding='same', name='conv5'),
        Flatten(name='flatten'),
        Dense(128, activation='relu', name='fc1'),
        Dense(64, activation='relu', name='fc2'),
        Dense(10, activation='softmax', name='output')
        ])
# Out:
# 2024-10-29 20:22:54.078800: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:22:54.178156: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:22:54.178277: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:22:54.181418: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:22:54.181512: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:22:54.181592: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:22:54.242592: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:22:54.242953: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:22:54.243013: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:236] Using CUDA malloc Async allocator for GPU: 0
# 2024-10-29 20:22:54.243101: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:22:54.243172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7960 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  conv7 (Conv2D)              (None, 4, 4, 256)         295168
#
#  pool4 (MaxPooling2D)        (None, 2, 2, 256)         0
#
#  dropout_3 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  fc1 (Dense)                 (None, 128)               131200
#
#  fc2 (Dense)                 (None, 64)                8256
#
#  output (Dense)              (None, 10)                650
#
# =================================================================
# Total params: 722282 (2.76 MB)
# Trainable params: 722282 (2.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def get_flops(model, input_shape):
    # Create a concrete function from the Keras model
    @tf.function
    def model_func(x):
        return model(x)
    
    # Get the concrete function
    concrete_func = model_func.get_concrete_function(tf.TensorSpec(input_shape, model.inputs[0].dtype))
    
    # Convert variables to constants and get the frozen graph
    frozen_func = convert_variables_to_constants_v2(concrete_func)
    frozen_graph = frozen_func.graph.as_graph_def()
    
    # Use TensorFlow's profiler
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(frozen_graph, name='')
        run_meta = tf.compat.v1.RunMetadata()
        with tf.compat.v1.Session(graph=graph) as sess:
            flops = tf.compat.v1.profiler.profile(
                graph=graph,
                run_meta=run_meta,
                cmd='op',
                options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
            )
            return flops.total_float_ops

# %%
'''for i in model_list:
    i.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    i.fit(X, y_one_hot, epochs=100, batch_size=2)
    loss_list.append(i.evaluate(X, y_one_hot)[0])
    accuracy_list.append(i.evaluate(X, y_one_hot)[1])'''
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, epochs=100, batch_size=64, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/100
# 2024-10-29 20:22:56.964013: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-10-29 20:22:57.108718: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-10-29 20:22:58.131686: I external/local_xla/xla/service/service.cc:168] XLA service 0x78585f6fc9d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-29 20:22:58.131703: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2024-10-29 20:22:58.147111: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730200978.228103 1338815 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 625/625 [==============================] - 9s 8ms/step - loss: 1.7786 - accuracy: 0.3237 - val_loss: 1.4335 - val_accuracy: 0.4664
# Epoch 2/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.3477 - accuracy: 0.5076 - val_loss: 1.2274 - val_accuracy: 0.5525
# Epoch 3/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.1542 - accuracy: 0.5844 - val_loss: 0.9899 - val_accuracy: 0.6494
# Epoch 4/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.0379 - accuracy: 0.6288 - val_loss: 0.9646 - val_accuracy: 0.6477
# Epoch 5/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.9457 - accuracy: 0.6678 - val_loss: 0.8484 - val_accuracy: 0.7008
# Epoch 6/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.8669 - accuracy: 0.6927 - val_loss: 0.8005 - val_accuracy: 0.7124
# Epoch 7/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.8112 - accuracy: 0.7131 - val_loss: 0.7484 - val_accuracy: 0.7352
# Epoch 8/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7572 - accuracy: 0.7340 - val_loss: 0.7284 - val_accuracy: 0.7467
# Epoch 9/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7214 - accuracy: 0.7473 - val_loss: 0.7327 - val_accuracy: 0.7471
# Epoch 10/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.6916 - accuracy: 0.7548 - val_loss: 0.7067 - val_accuracy: 0.7533
# Epoch 11/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.6637 - accuracy: 0.7674 - val_loss: 0.7197 - val_accuracy: 0.7503
# Epoch 12/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.6388 - accuracy: 0.7763 - val_loss: 0.6928 - val_accuracy: 0.7633
# Epoch 13/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.6060 - accuracy: 0.7844 - val_loss: 0.6464 - val_accuracy: 0.7751
# Epoch 14/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5905 - accuracy: 0.7926 - val_loss: 0.6341 - val_accuracy: 0.7797
# Epoch 15/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5814 - accuracy: 0.7976 - val_loss: 0.6592 - val_accuracy: 0.7713
# Epoch 16/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5680 - accuracy: 0.8000 - val_loss: 0.6333 - val_accuracy: 0.7830
# Epoch 17/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5525 - accuracy: 0.8056 - val_loss: 0.6141 - val_accuracy: 0.7950
# Epoch 18/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5404 - accuracy: 0.8088 - val_loss: 0.6419 - val_accuracy: 0.7803
# Epoch 19/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5264 - accuracy: 0.8119 - val_loss: 0.6104 - val_accuracy: 0.7925
# Epoch 20/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5167 - accuracy: 0.8171 - val_loss: 0.6542 - val_accuracy: 0.7840
# Epoch 21/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5083 - accuracy: 0.8201 - val_loss: 0.6641 - val_accuracy: 0.7771
# Epoch 22/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.4936 - accuracy: 0.8275 - val_loss: 0.5989 - val_accuracy: 0.8031
# Epoch 23/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4868 - accuracy: 0.8287 - val_loss: 0.6273 - val_accuracy: 0.7961
# Epoch 24/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4725 - accuracy: 0.8336 - val_loss: 0.6001 - val_accuracy: 0.7941
# Epoch 25/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4771 - accuracy: 0.8317 - val_loss: 0.6061 - val_accuracy: 0.7908
# Epoch 26/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4610 - accuracy: 0.8393 - val_loss: 0.6048 - val_accuracy: 0.8024
# Epoch 27/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4569 - accuracy: 0.8386 - val_loss: 0.5813 - val_accuracy: 0.8104
# Epoch 28/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4445 - accuracy: 0.8425 - val_loss: 0.5849 - val_accuracy: 0.8076
# Epoch 29/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4332 - accuracy: 0.8457 - val_loss: 0.5865 - val_accuracy: 0.8040
# Epoch 30/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4305 - accuracy: 0.8464 - val_loss: 0.5976 - val_accuracy: 0.8029
# Epoch 31/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4259 - accuracy: 0.8499 - val_loss: 0.5703 - val_accuracy: 0.8108
# Epoch 32/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4159 - accuracy: 0.8528 - val_loss: 0.6345 - val_accuracy: 0.7974
# Epoch 33/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4190 - accuracy: 0.8516 - val_loss: 0.5892 - val_accuracy: 0.8122
# Epoch 34/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4037 - accuracy: 0.8572 - val_loss: 0.5622 - val_accuracy: 0.8130
# Epoch 35/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4115 - accuracy: 0.8546 - val_loss: 0.5911 - val_accuracy: 0.8089
# Epoch 36/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4036 - accuracy: 0.8563 - val_loss: 0.5862 - val_accuracy: 0.8068
# Epoch 37/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3923 - accuracy: 0.8606 - val_loss: 0.5824 - val_accuracy: 0.8102
# Epoch 38/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3976 - accuracy: 0.8596 - val_loss: 0.5710 - val_accuracy: 0.8163
# Epoch 39/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3810 - accuracy: 0.8651 - val_loss: 0.5701 - val_accuracy: 0.8125
# Epoch 40/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3804 - accuracy: 0.8651 - val_loss: 0.6105 - val_accuracy: 0.8056
# Epoch 41/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3780 - accuracy: 0.8676 - val_loss: 0.5631 - val_accuracy: 0.8214
# Epoch 42/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3773 - accuracy: 0.8671 - val_loss: 0.6148 - val_accuracy: 0.7995
# Epoch 43/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3579 - accuracy: 0.8760 - val_loss: 0.5605 - val_accuracy: 0.8180
# Epoch 44/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3587 - accuracy: 0.8758 - val_loss: 0.5773 - val_accuracy: 0.8087
# Epoch 45/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3649 - accuracy: 0.8720 - val_loss: 0.5893 - val_accuracy: 0.8114
# Epoch 46/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3572 - accuracy: 0.8756 - val_loss: 0.6024 - val_accuracy: 0.8077
# Epoch 47/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3565 - accuracy: 0.8753 - val_loss: 0.5800 - val_accuracy: 0.8101
# Epoch 48/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3537 - accuracy: 0.8772 - val_loss: 0.5714 - val_accuracy: 0.8178
# Epoch 49/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3440 - accuracy: 0.8808 - val_loss: 0.5661 - val_accuracy: 0.8219
# Epoch 50/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3435 - accuracy: 0.8798 - val_loss: 0.6126 - val_accuracy: 0.8045
# Epoch 51/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3445 - accuracy: 0.8795 - val_loss: 0.6080 - val_accuracy: 0.8091
# Epoch 52/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3426 - accuracy: 0.8808 - val_loss: 0.5734 - val_accuracy: 0.8148
# Epoch 53/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3295 - accuracy: 0.8853 - val_loss: 0.5715 - val_accuracy: 0.8163
# Epoch 54/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3328 - accuracy: 0.8854 - val_loss: 0.5912 - val_accuracy: 0.8191
# Epoch 55/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3326 - accuracy: 0.8834 - val_loss: 0.5616 - val_accuracy: 0.8197
# Epoch 56/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3283 - accuracy: 0.8852 - val_loss: 0.5714 - val_accuracy: 0.8156
# Epoch 57/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3172 - accuracy: 0.8896 - val_loss: 0.5929 - val_accuracy: 0.8115
# Epoch 58/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3222 - accuracy: 0.8866 - val_loss: 0.5502 - val_accuracy: 0.8218
# Epoch 59/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3124 - accuracy: 0.8902 - val_loss: 0.5819 - val_accuracy: 0.8115
# Epoch 60/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3110 - accuracy: 0.8920 - val_loss: 0.5997 - val_accuracy: 0.8124
# Epoch 61/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3215 - accuracy: 0.8887 - val_loss: 0.6283 - val_accuracy: 0.8045
# Epoch 62/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3145 - accuracy: 0.8897 - val_loss: 0.5433 - val_accuracy: 0.8230
# Epoch 63/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3166 - accuracy: 0.8901 - val_loss: 0.5764 - val_accuracy: 0.8134
# Epoch 64/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3117 - accuracy: 0.8918 - val_loss: 0.5626 - val_accuracy: 0.8244
# Epoch 65/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3015 - accuracy: 0.8968 - val_loss: 0.5658 - val_accuracy: 0.8247
# Epoch 66/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3150 - accuracy: 0.8921 - val_loss: 0.5604 - val_accuracy: 0.8255
# Epoch 67/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2993 - accuracy: 0.8978 - val_loss: 0.5669 - val_accuracy: 0.8253
# Epoch 68/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2952 - accuracy: 0.8986 - val_loss: 0.5657 - val_accuracy: 0.8202
# Epoch 69/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2991 - accuracy: 0.8957 - val_loss: 0.5973 - val_accuracy: 0.8140
# Epoch 70/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2962 - accuracy: 0.8973 - val_loss: 0.5844 - val_accuracy: 0.8210
# Epoch 71/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2935 - accuracy: 0.8998 - val_loss: 0.6130 - val_accuracy: 0.8153
# Epoch 72/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2979 - accuracy: 0.8978 - val_loss: 0.5775 - val_accuracy: 0.8272
# Epoch 73/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2910 - accuracy: 0.9002 - val_loss: 0.5757 - val_accuracy: 0.8225
# Epoch 74/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2855 - accuracy: 0.9020 - val_loss: 0.5735 - val_accuracy: 0.8227
# Epoch 75/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2844 - accuracy: 0.9033 - val_loss: 0.5698 - val_accuracy: 0.8269
# Epoch 76/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2818 - accuracy: 0.9043 - val_loss: 0.5641 - val_accuracy: 0.8246
# Epoch 77/100
# 625/625 [==============================] - 5s 9ms/step - loss: 0.2780 - accuracy: 0.9043 - val_loss: 0.5852 - val_accuracy: 0.8222
# Epoch 78/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2801 - accuracy: 0.9034 - val_loss: 0.5863 - val_accuracy: 0.8205
# Epoch 79/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2745 - accuracy: 0.9065 - val_loss: 0.5658 - val_accuracy: 0.8188
# Epoch 80/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2752 - accuracy: 0.9060 - val_loss: 0.5861 - val_accuracy: 0.8216
# Epoch 81/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2698 - accuracy: 0.9079 - val_loss: 0.5661 - val_accuracy: 0.8303
# Epoch 82/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2688 - accuracy: 0.9085 - val_loss: 0.6023 - val_accuracy: 0.8257
# Epoch 83/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2693 - accuracy: 0.9080 - val_loss: 0.5711 - val_accuracy: 0.8284
# Epoch 84/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2715 - accuracy: 0.9082 - val_loss: 0.6388 - val_accuracy: 0.8146
# Epoch 85/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2709 - accuracy: 0.9087 - val_loss: 0.5878 - val_accuracy: 0.8274
# Epoch 86/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2736 - accuracy: 0.9076 - val_loss: 0.6162 - val_accuracy: 0.8253
# Epoch 87/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2739 - accuracy: 0.9078 - val_loss: 0.5895 - val_accuracy: 0.8255
# Epoch 88/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2640 - accuracy: 0.9108 - val_loss: 0.5646 - val_accuracy: 0.8292
# Epoch 89/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2686 - accuracy: 0.9103 - val_loss: 0.5764 - val_accuracy: 0.8250
# Epoch 90/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2600 - accuracy: 0.9132 - val_loss: 0.5862 - val_accuracy: 0.8236
# Epoch 91/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2521 - accuracy: 0.9145 - val_loss: 0.6205 - val_accuracy: 0.8193
# Epoch 92/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2620 - accuracy: 0.9107 - val_loss: 0.5912 - val_accuracy: 0.8261
# Epoch 93/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2595 - accuracy: 0.9135 - val_loss: 0.6070 - val_accuracy: 0.8219
# Epoch 94/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2482 - accuracy: 0.9155 - val_loss: 0.5682 - val_accuracy: 0.8315
# Epoch 95/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2514 - accuracy: 0.9157 - val_loss: 0.5873 - val_accuracy: 0.8274
# Epoch 96/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2606 - accuracy: 0.9135 - val_loss: 0.5849 - val_accuracy: 0.8283
# Epoch 97/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2577 - accuracy: 0.9144 - val_loss: 0.6037 - val_accuracy: 0.8253
# Epoch 98/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.2556 - accuracy: 0.9129 - val_loss: 0.5897 - val_accuracy: 0.8297
# Epoch 99/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2511 - accuracy: 0.9158 - val_loss: 0.5804 - val_accuracy: 0.8284
# Epoch 100/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2558 - accuracy: 0.9138 - val_loss: 0.5784 - val_accuracy: 0.8288

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.6247 - accuracy: 0.8227 - 677ms/epoch - 2ms/step

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()

# %%
#for idx, model in enumerate(model_list):
#    model.save(f'model_{idx}.h5')
get_flops(model, train_images.shape)
# Out:
# WARNING:tensorflow:From /home/am/Documents/VirtualEnv/tensorflow-gpu/lib/python3.11/site-packages/tensorflow/python/ops/nn_ops.py:5256: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# 2024-10-29 20:30:31.306910: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.306997: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-10-29 20:30:31.307262: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-10-29 20:30:31.307654: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.307742: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.307815: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.307918: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.308002: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.308056: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7960 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-10-29 20:30:31.507527: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.507706: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.507789: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.507897: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.507976: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:30:31.508029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7960 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# =========================Options=============================
# 3486576480000
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   3468.17b float_ops (100.00%, 99.47%)
# MatMul                   11.19b float_ops (0.53%, 0.32%)
# BiasAdd                  4.76b float_ops (0.21%, 0.14%)
# MaxPool                  2.46b float_ops (0.07%, 0.07%)
# Softmax                  2.00m float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================

# %%
def get_layer(model, layer_index):
    return [layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)][layer_index]

def get_filters(model, layer_index, filter_indices):
    layer = get_layer(model, layer_index)
    filters, biases = layer.get_weights()
    return filters[:, :, :, filter_indices]

def get_all_filters(model, layer_name):
    layer = model.get_layer(name=layer_name)
    filters, biases = layer.get_weights()
    return filters

# %%
get_all_filters(model, 'conv3').shape
# Out:
# (3, 3, 32, 64)

# %%
layer_name = 'conv3'
intermediate_model = models.Model(inputs=model.input, outputs=model.get_layer(layer_name).output)
feature_maps = intermediate_model.predict(train_images[:1000])

np.linalg.norm(feature_maps[:,:,:,31]) - np.linalg.norm(feature_maps)
# Out:
# 32/32 [==============================] - 0s 5ms/step
# -676.37683

# %%
num_filters = feature_maps.shape[-1]
grid_size = int(np.ceil(np.sqrt(num_filters)))  # Set up a square grid if possible

# Plot each filter's feature map with larger image size
fig, axes = plt.subplots(grid_size, grid_size, figsize=(20, 20))  # Adjust `figsize` as needed

for i in range(num_filters):
    row = i // grid_size
    col = i % grid_size
    axes[row, col].imshow(feature_maps[0, :, :, i], cmap='viridis')
    axes[row, col].axis('off')
    axes[row, col].set_title(f'Filter {i+1}', fontsize=8)

# Hide any unused subplots
for i in range(num_filters, grid_size * grid_size):
    fig.delaxes(axes.flatten()[i])

plt.tight_layout()
plt.show()

# %%
plt.imshow(train_images[0])

# %%
feature_maps[0].shape
# Out:
# (16, 16, 64)

# %%
'''def norms(model_index, layer_index, model_list):    
    model_norm_list = []
    for model_idx, model in enumerate(model_list):
        #print(model_idx)
        layer_norm_list = []
        for layer_idx, layer in enumerate([layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)]):
            #print(layer_idx)
            norm_list = []
            filters, biases = layer.get_weights()
            num_filters = filters.shape[-1]
            for i in range(num_filters):
                
                filt = filters[:, :, :, i]
                filt_matrix = filt.reshape(-1, filt.shape[-1])
                norm = np.linalg.norm(filt_matrix)
                norm_list.append(norm)
            layer_norm_list.append(norm_list)
        model_norm_list.append(layer_norm_list)
    return model_norm_list[model_index][layer_index]'''

'''def get_norm(model, layer_name):
    layer = model.get_layer(layer_name)
    filters, biases = layer.get_weights()
    num_filters = filters.shape[-1]
    norms = []
    for i in range(num_filters):
        filt = filters[:, :, :, i]
        filt_matrix = filt.reshape(-1, filt.shape[-1])
        norm = np.linalg.norm(filt_matrix)
        norms.append(norm)
    return norms'''

'''def get_filter_uniqueness(model, layer_name):
    layer = model.get_layer(layer_name)
    filters, biases = layer.get_weights()
    num_filters = filters.shape[-1]
    uniqueness_list = []
    for i in range(num_filters):
        filt = filters[:, :, :, i]
        filt_matrix = filt.reshape(-1, filt.shape[-1])
        uniqueness = np.linalg.norm(filt_matrix) - np.linalg.norm(get_all_filters(model, layer_name))

        uniqueness_list.append(uniqueness)
    return uniqueness_list'''

def get_feature_map_uniqueness(model, layer_name):
    intermediate_model = models.Model(inputs=model.input, outputs=model.get_layer(layer_name).output)
    feature_maps = intermediate_model.predict(train_images[:1000])
    layer = model.get_layer(layer_name)
    filters, biases = layer.get_weights()
    num_filters = filters.shape[-1]
    feature_uniqueness_list = []
    for i in range(num_filters):
        feature_uniqueness_list.append(np.abs(np.linalg.norm(feature_maps[:,:,:,i]) - np.linalg.norm(feature_maps)))
    return feature_uniqueness_list





feat_unique_conv3 = get_feature_map_uniqueness(model, 'conv3')
feat_unique_conv4 = get_feature_map_uniqueness(model, 'conv4')
feat_unique_conv5 = get_feature_map_uniqueness(model, 'conv5')
feat_unique_conv6 = get_feature_map_uniqueness(model, 'conv6')
feat_unique_conv7 = get_feature_map_uniqueness(model, 'conv7')
# Out:
# 32/32 [==============================] - 0s 890us/step
# 32/32 [==============================] - 0s 817us/step
# 32/32 [==============================] - 0s 838us/step
# 32/32 [==============================] - 0s 862us/step
# 32/32 [==============================] - 0s 994us/step

# %%
def filter_to_zero(norms, percentage):
    threshold = np.percentile(norms, percentage)
    return [i for i, norm in enumerate(norms) if norm < threshold]

def filter_to_keep(norms, percentage):
    threshold = np.percentile(norms, percentage)
    return [i for i, norm in enumerate(norms) if norm >= threshold]

# %%
keep_filt_conv3 = filter_to_keep(feat_unique_conv3, 50)
keep_filt_conv4 = filter_to_keep(feat_unique_conv4, 50)
keep_filt_conv5 = filter_to_keep(feat_unique_conv5, 70)
keep_filt_conv6 = filter_to_keep(feat_unique_conv6, 70)
keep_filt_conv7 = filter_to_keep(feat_unique_conv7, 90)

# %%
'''pruned_target_model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=X.shape[1:], name='target_conv1'),
        MaxPooling2D((2,2), name='target_pool1'),
        Conv2D(len(keep_filt), (3,3), activation='relu', name='target_conv2'),
        MaxPooling2D((2,2), name='target_pool2'),
        Flatten(name='target_flatten'),
        Dense(len(keep_filt), activation='relu', name='target_fc1'),
        Dense(10, activation='softmax', name='target_output')
        ])'''

pruned_target_model = Sequential([
        Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3), name='conv1'),
        Conv2D(32, (3,3), activation='relu', padding='same', name='conv2'),
        MaxPooling2D((2,2), name='pool1'),
        Dropout(0.25),

        Conv2D(len(keep_filt_conv3), (3,3), activation='relu', padding='same', name='conv3'),
        Conv2D(len(keep_filt_conv4), (3,3), activation='relu', padding='same',  name='conv4'),
        MaxPooling2D((2,2), name='pool2'),
        Dropout(0.25),

        Conv2D(len(keep_filt_conv5), (3,3), activation='relu', padding='same',  name='conv5'),
        Conv2D(len(keep_filt_conv6), (3,3), activation='relu', padding='same',  name='conv6'),
        MaxPooling2D((2,2), name='pool3'),
        Dropout(0.25),

        Conv2D(len(keep_filt_conv7), (3,3), activation='relu', padding='same',  name='conv7'),
        MaxPooling2D((2,2), name='pool4'),
        Dropout(0.25),
        #Conv2D(128, (3,3), activation='relu', padding='same', name='conv5'),
        Flatten(name='flatten'),
        Dense(len(keep_filt_conv7), activation='relu', name='fc1'),
        Dense(64, activation='relu', name='fc2'),
        Dense(10, activation='softmax', name='output')
        ])

# %%
pruned_target_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  dropout_8 (Dropout)         (None, 16, 16, 32)        0
#
#  conv3 (Conv2D)              (None, 16, 16, 32)        9248
#
#  conv4 (Conv2D)              (None, 16, 16, 32)        9248
#
#  pool2 (MaxPooling2D)        (None, 8, 8, 32)          0
#
#  dropout_9 (Dropout)         (None, 8, 8, 32)          0
#
#  conv5 (Conv2D)              (None, 8, 8, 39)          11271
#
#  conv6 (Conv2D)              (None, 8, 8, 39)          13728
#
#  pool3 (MaxPooling2D)        (None, 4, 4, 39)          0
#
#  dropout_10 (Dropout)        (None, 4, 4, 39)          0
#
#  conv7 (Conv2D)              (None, 4, 4, 26)          9152
#
#  pool4 (MaxPooling2D)        (None, 2, 2, 26)          0
#
#  dropout_11 (Dropout)        (None, 2, 2, 26)          0
#
#  flatten (Flatten)           (None, 104)               0
#
#  fc1 (Dense)                 (None, 26)                2730
#
#  fc2 (Dense)                 (None, 64)                1728
#
#  output (Dense)              (None, 10)                650
#
# =================================================================
# Total params: 67899 (265.23 KB)
# Trainable params: 67899 (265.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
'''def copy_weights_pruned(source_model, pruned_target_model, source_layer_name, target_layer_name):
    for source_layer, target_layer in zip(source_model.layers, pruned_target_model.layers):
        if isinstance(source_layer, tf.keras.layers.Conv2D) and source_layer.name != source_layer_name and target_layer.name != target_layer_name:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w, b])
        elif source_layer.name == source_layer_name and target_layer.name == target_layer_name:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w[:, :, :, keep_filt], b[keep_filt]])'''
def get_var_name(var):
    for name, value in locals().items():
        if value is var:
            return name

def copy_weights_pruned(source_model, pruned_target_model, source_layer_names, target_layer_names, keep_filters):
    for source_layer, target_layer in zip(source_model.layers, pruned_target_model.layers):
        if isinstance(source_layer, tf.keras.layers.Conv2D) and source_layer.name not in source_layer_names and target_layer.name not in target_layer_names:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w, b])
        elif source_layer.name in source_layer_names and target_layer.name in target_layer_names:
            for keep_filt in keep_filters:
                if source_layer.name in get_var_name(keep_filt):
                    w, b = source_layer.get_weights()
                    target_layer.set_weights([w[:, :, :, keep_filt], b[keep_filt]])

# %%
copy_weights_pruned(model, pruned_target_model, [ 'conv3', 'conv4', 'conv5', 'conv6', 'conv7'], [ 'conv3', 'conv4', 'conv5', 'conv6', 'conv7'], [ keep_filt_conv3, keep_filt_conv4, keep_filt_conv5, keep_filt_conv6, keep_filt_conv7])

# %%
pruned_target_model.get_layer('conv3').get_weights()[0].shape
# Out:
# (3, 3, 32, 32)

# %%
pruned_target_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = pruned_target_model.fit(train_images, train_labels, epochs=100, batch_size=64, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/100
# 2024-10-30 15:58:00.901661: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_2/dropout_8/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 625/625 [==============================] - 5s 6ms/step - loss: 1.7362 - accuracy: 0.3172 - val_loss: 1.3194 - val_accuracy: 0.4995
# Epoch 2/100
# 625/625 [==============================] - 3s 5ms/step - loss: 1.2962 - accuracy: 0.5220 - val_loss: 1.0616 - val_accuracy: 0.6118
# Epoch 3/100
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0966 - accuracy: 0.6074 - val_loss: 0.9367 - val_accuracy: 0.6599
# Epoch 4/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9992 - accuracy: 0.6438 - val_loss: 0.8710 - val_accuracy: 0.6852
# Epoch 5/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9443 - accuracy: 0.6636 - val_loss: 0.8425 - val_accuracy: 0.6968
# Epoch 6/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.9044 - accuracy: 0.6775 - val_loss: 0.8051 - val_accuracy: 0.7080
# Epoch 7/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.8642 - accuracy: 0.6938 - val_loss: 0.8051 - val_accuracy: 0.7137
# Epoch 8/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8448 - accuracy: 0.7001 - val_loss: 0.8309 - val_accuracy: 0.7025
# Epoch 9/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8267 - accuracy: 0.7075 - val_loss: 0.7486 - val_accuracy: 0.7383
# Epoch 10/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8032 - accuracy: 0.7162 - val_loss: 0.7227 - val_accuracy: 0.7413
# Epoch 11/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7846 - accuracy: 0.7269 - val_loss: 0.7262 - val_accuracy: 0.7448
# Epoch 12/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7731 - accuracy: 0.7273 - val_loss: 0.7097 - val_accuracy: 0.7510
# Epoch 13/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7610 - accuracy: 0.7334 - val_loss: 0.6967 - val_accuracy: 0.7562
# Epoch 14/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7440 - accuracy: 0.7395 - val_loss: 0.6809 - val_accuracy: 0.7621
# Epoch 15/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7327 - accuracy: 0.7440 - val_loss: 0.6900 - val_accuracy: 0.7583
# Epoch 16/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7226 - accuracy: 0.7456 - val_loss: 0.7069 - val_accuracy: 0.7507
# Epoch 17/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7180 - accuracy: 0.7516 - val_loss: 0.6865 - val_accuracy: 0.7618
# Epoch 18/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7093 - accuracy: 0.7529 - val_loss: 0.6700 - val_accuracy: 0.7701
# Epoch 19/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7012 - accuracy: 0.7588 - val_loss: 0.6688 - val_accuracy: 0.7653
# Epoch 20/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6942 - accuracy: 0.7594 - val_loss: 0.6826 - val_accuracy: 0.7586
# Epoch 21/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6813 - accuracy: 0.7636 - val_loss: 0.6598 - val_accuracy: 0.7708
# Epoch 22/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6732 - accuracy: 0.7661 - val_loss: 0.6472 - val_accuracy: 0.7721
# Epoch 23/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6766 - accuracy: 0.7649 - val_loss: 0.6352 - val_accuracy: 0.7821
# Epoch 24/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6646 - accuracy: 0.7707 - val_loss: 0.6308 - val_accuracy: 0.7815
# Epoch 25/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6575 - accuracy: 0.7709 - val_loss: 0.6702 - val_accuracy: 0.7670
# Epoch 26/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6527 - accuracy: 0.7734 - val_loss: 0.6489 - val_accuracy: 0.7730
# Epoch 27/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6519 - accuracy: 0.7753 - val_loss: 0.6196 - val_accuracy: 0.7865
# Epoch 28/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6500 - accuracy: 0.7725 - val_loss: 0.6444 - val_accuracy: 0.7758
# Epoch 29/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6420 - accuracy: 0.7779 - val_loss: 0.6492 - val_accuracy: 0.7753
# Epoch 30/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6382 - accuracy: 0.7778 - val_loss: 0.6533 - val_accuracy: 0.7739
# Epoch 31/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6340 - accuracy: 0.7790 - val_loss: 0.6339 - val_accuracy: 0.7798
# Epoch 32/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6306 - accuracy: 0.7795 - val_loss: 0.6292 - val_accuracy: 0.7862
# Epoch 33/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.6327 - accuracy: 0.7821 - val_loss: 0.6167 - val_accuracy: 0.7865
# Epoch 34/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6257 - accuracy: 0.7831 - val_loss: 0.6184 - val_accuracy: 0.7887
# Epoch 35/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6265 - accuracy: 0.7853 - val_loss: 0.6365 - val_accuracy: 0.7824
# Epoch 36/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6188 - accuracy: 0.7851 - val_loss: 0.6114 - val_accuracy: 0.7886
# Epoch 37/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6151 - accuracy: 0.7862 - val_loss: 0.6033 - val_accuracy: 0.7947
# Epoch 38/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6169 - accuracy: 0.7872 - val_loss: 0.6037 - val_accuracy: 0.7956
# Epoch 39/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6111 - accuracy: 0.7885 - val_loss: 0.6183 - val_accuracy: 0.7907
# Epoch 40/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6083 - accuracy: 0.7887 - val_loss: 0.6031 - val_accuracy: 0.7934
# Epoch 41/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.6102 - accuracy: 0.7876 - val_loss: 0.5804 - val_accuracy: 0.8019
# Epoch 42/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5960 - accuracy: 0.7950 - val_loss: 0.6532 - val_accuracy: 0.7790
# Epoch 43/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6017 - accuracy: 0.7910 - val_loss: 0.6406 - val_accuracy: 0.7799
# Epoch 44/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5946 - accuracy: 0.7952 - val_loss: 0.5937 - val_accuracy: 0.8016
# Epoch 45/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5932 - accuracy: 0.7960 - val_loss: 0.5904 - val_accuracy: 0.7978
# Epoch 46/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5902 - accuracy: 0.7980 - val_loss: 0.6138 - val_accuracy: 0.7930
# Epoch 47/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.5867 - accuracy: 0.7980 - val_loss: 0.5823 - val_accuracy: 0.8010
# Epoch 48/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5887 - accuracy: 0.7962 - val_loss: 0.5904 - val_accuracy: 0.7991
# Epoch 49/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5830 - accuracy: 0.7976 - val_loss: 0.6068 - val_accuracy: 0.7942
# Epoch 50/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5779 - accuracy: 0.7993 - val_loss: 0.5758 - val_accuracy: 0.8032
# Epoch 51/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5753 - accuracy: 0.8004 - val_loss: 0.5904 - val_accuracy: 0.7982
# Epoch 52/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5807 - accuracy: 0.7972 - val_loss: 0.5892 - val_accuracy: 0.7965
# Epoch 53/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5754 - accuracy: 0.8015 - val_loss: 0.6052 - val_accuracy: 0.7973
# Epoch 54/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5755 - accuracy: 0.7995 - val_loss: 0.5954 - val_accuracy: 0.7971
# Epoch 55/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5776 - accuracy: 0.8019 - val_loss: 0.6115 - val_accuracy: 0.7956
# Epoch 56/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5671 - accuracy: 0.8037 - val_loss: 0.5929 - val_accuracy: 0.7975
# Epoch 57/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5684 - accuracy: 0.8043 - val_loss: 0.5918 - val_accuracy: 0.7981
# Epoch 58/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5631 - accuracy: 0.8044 - val_loss: 0.5993 - val_accuracy: 0.7971
# Epoch 59/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5620 - accuracy: 0.8066 - val_loss: 0.6014 - val_accuracy: 0.7986
# Epoch 60/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5590 - accuracy: 0.8056 - val_loss: 0.6038 - val_accuracy: 0.7988
# Epoch 61/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5660 - accuracy: 0.8041 - val_loss: 0.6063 - val_accuracy: 0.7942
# Epoch 62/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5613 - accuracy: 0.8067 - val_loss: 0.6193 - val_accuracy: 0.7934
# Epoch 63/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5588 - accuracy: 0.8066 - val_loss: 0.5778 - val_accuracy: 0.8046
# Epoch 64/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5603 - accuracy: 0.8053 - val_loss: 0.5659 - val_accuracy: 0.8073
# Epoch 65/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5585 - accuracy: 0.8059 - val_loss: 0.6148 - val_accuracy: 0.7918
# Epoch 66/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5560 - accuracy: 0.8073 - val_loss: 0.6024 - val_accuracy: 0.7932
# Epoch 67/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5571 - accuracy: 0.8074 - val_loss: 0.5938 - val_accuracy: 0.7933
# Epoch 68/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5543 - accuracy: 0.8079 - val_loss: 0.5837 - val_accuracy: 0.8012
# Epoch 69/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5504 - accuracy: 0.8078 - val_loss: 0.5972 - val_accuracy: 0.7968
# Epoch 70/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5494 - accuracy: 0.8100 - val_loss: 0.5951 - val_accuracy: 0.7988
# Epoch 71/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5469 - accuracy: 0.8113 - val_loss: 0.5770 - val_accuracy: 0.8071
# Epoch 72/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5494 - accuracy: 0.8114 - val_loss: 0.5896 - val_accuracy: 0.7953
# Epoch 73/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5438 - accuracy: 0.8124 - val_loss: 0.5886 - val_accuracy: 0.8006
# Epoch 74/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5476 - accuracy: 0.8121 - val_loss: 0.5703 - val_accuracy: 0.8057
# Epoch 75/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5419 - accuracy: 0.8138 - val_loss: 0.5729 - val_accuracy: 0.8073
# Epoch 76/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5440 - accuracy: 0.8114 - val_loss: 0.6114 - val_accuracy: 0.7927
# Epoch 77/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5371 - accuracy: 0.8141 - val_loss: 0.5743 - val_accuracy: 0.8058
# Epoch 78/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5413 - accuracy: 0.8126 - val_loss: 0.5862 - val_accuracy: 0.8003
# Epoch 79/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5424 - accuracy: 0.8129 - val_loss: 0.5783 - val_accuracy: 0.8017
# Epoch 80/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5339 - accuracy: 0.8135 - val_loss: 0.6061 - val_accuracy: 0.7911
# Epoch 81/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5351 - accuracy: 0.8151 - val_loss: 0.5835 - val_accuracy: 0.8028
# Epoch 82/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5358 - accuracy: 0.8135 - val_loss: 0.5654 - val_accuracy: 0.8078
# Epoch 83/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5319 - accuracy: 0.8149 - val_loss: 0.5800 - val_accuracy: 0.8069
# Epoch 84/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5330 - accuracy: 0.8159 - val_loss: 0.6199 - val_accuracy: 0.7991
# Epoch 85/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5285 - accuracy: 0.8195 - val_loss: 0.5849 - val_accuracy: 0.8025
# Epoch 86/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5292 - accuracy: 0.8156 - val_loss: 0.5506 - val_accuracy: 0.8152
# Epoch 87/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5304 - accuracy: 0.8163 - val_loss: 0.5702 - val_accuracy: 0.8068
# Epoch 88/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5250 - accuracy: 0.8186 - val_loss: 0.5782 - val_accuracy: 0.8080
# Epoch 89/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5345 - accuracy: 0.8161 - val_loss: 0.5530 - val_accuracy: 0.8085
# Epoch 90/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.5246 - accuracy: 0.8188 - val_loss: 0.5728 - val_accuracy: 0.8083
# Epoch 91/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.5226 - accuracy: 0.8211 - val_loss: 0.5910 - val_accuracy: 0.8043
# Epoch 92/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5257 - accuracy: 0.8197 - val_loss: 0.5669 - val_accuracy: 0.8066
# Epoch 93/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5283 - accuracy: 0.8185 - val_loss: 0.5744 - val_accuracy: 0.8072
# Epoch 94/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5253 - accuracy: 0.8167 - val_loss: 0.5467 - val_accuracy: 0.8114
# Epoch 95/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5236 - accuracy: 0.8194 - val_loss: 0.5664 - val_accuracy: 0.8080
# Epoch 96/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.5193 - accuracy: 0.8196 - val_loss: 0.5824 - val_accuracy: 0.7998
# Epoch 97/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5229 - accuracy: 0.8195 - val_loss: 0.6646 - val_accuracy: 0.7711
# Epoch 98/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5145 - accuracy: 0.8221 - val_loss: 0.5585 - val_accuracy: 0.8090
# Epoch 99/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5153 - accuracy: 0.8199 - val_loss: 0.5876 - val_accuracy: 0.8042
# Epoch 100/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5139 - accuracy: 0.8206 - val_loss: 0.5646 - val_accuracy: 0.8117

# %%
test_loss, test_acc = pruned_target_model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 0s - loss: 0.5942 - accuracy: 0.8074 - 488ms/epoch - 2ms/step

# %%
get_flops(pruned_target_model, train_images.shape)
# Out:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   1342.52b float_ops (100.00%, 99.58%)
# BiasAdd                  3.50b float_ops (0.42%, 0.26%)
# MaxPool                  1.75b float_ops (0.16%, 0.13%)
# MatMul                   400.64m float_ops (0.03%, 0.03%)
# Softmax                  2.00m float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
# 2024-10-29 20:36:50.929914: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:50.930009: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-10-29 20:36:50.930276: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-10-29 20:36:50.930585: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:50.930830: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:50.930914: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:50.931118: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:50.931199: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:50.931252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7960 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-10-29 20:36:51.103677: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:51.103841: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:51.103922: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:51.104026: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:51.104103: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 20:36:51.104155: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7960 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 1348172400000

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()

# %%
model.save('model_feature_uniqueness.h5')
pruned_target_model.save('pruned_target_model_feature_uniqueness.h5')
# Out:
# /home/am/Documents/VirtualEnv/tensorflow-gpu/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
