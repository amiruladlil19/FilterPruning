# %%
import tensorflow as tf
import numpy as np
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import clone_model
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from numpy.random import default_rng
from tensorflow.keras.models import load_model
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
# Out:
# 2024-10-29 19:29:04.711867: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-29 19:29:04.737399: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-29 19:29:04.737423: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-29 19:29:04.738146: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-29 19:29:04.742639: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-29 19:29:05.251250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
plt.imshow(train_images[0])

# %%
num_classes = 10
train_labels = to_categorical(train_labels, num_classes)
test_labels = to_categorical(test_labels, num_classes)

# %%
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

# %%
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.flatten()

for img, lbl, ax in zip(train_images, train_labels, axes):
    ax.imshow(img)
    ax.set_title(f'Label: {lbl}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
'''model_list = []

for i in range(10):
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3), name='conv1'),
        MaxPooling2D((2,2), name='pool1'),
        Conv2D(64, (3,3), activation='relu', name='conv2'),
        MaxPooling2D((2,2), name='pool2'),
        Conv2D(64, (3,3), activation='relu', name='conv3'),
        Flatten(name='flatten'),
        Dense(64, activation='relu', name='fc1'),
        Dense(10, activation='softmax', name='output')
        ])
    model_list.append(model)'''
model = Sequential([
        Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3), name='conv1'),
        Conv2D(32, (3,3), activation='relu', padding='same', name='conv2'),
        MaxPooling2D((2,2), name='pool1'),
        Dropout(0.25),

        Conv2D(64, (3,3), activation='relu', padding='same', name='conv3'),
        Conv2D(64, (3,3), activation='relu', padding='same',  name='conv4'),
        MaxPooling2D((2,2), name='pool2'),
        Dropout(0.25),

        Conv2D(128, (3,3), activation='relu', padding='same',  name='conv5'),
        Conv2D(128, (3,3), activation='relu', padding='same',  name='conv6'),
        MaxPooling2D((2,2), name='pool3'),
        Dropout(0.25),

        Conv2D(256, (3,3), activation='relu', padding='same',  name='conv7'),
        MaxPooling2D((2,2), name='pool4'),
        Dropout(0.25),
        #Conv2D(128, (3,3), activation='relu', padding='same', name='conv5'),
        Flatten(name='flatten'),
        Dense(128, activation='relu', name='fc1'),
        Dense(64, activation='relu', name='fc2'),
        Dense(10, activation='softmax', name='output')
        ])
# Out:
# 2024-10-29 19:29:07.331503: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:29:07.352168: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:29:07.352306: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:29:07.353113: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:29:07.353204: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:29:07.353281: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:29:07.401485: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:29:07.401602: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:29:07.401659: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:236] Using CUDA malloc Async allocator for GPU: 0
# 2024-10-29 19:29:07.401744: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:29:07.401807: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9723 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  conv7 (Conv2D)              (None, 4, 4, 256)         295168
#
#  pool4 (MaxPooling2D)        (None, 2, 2, 256)         0
#
#  dropout_3 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  fc1 (Dense)                 (None, 128)               131200
#
#  fc2 (Dense)                 (None, 64)                8256
#
#  output (Dense)              (None, 10)                650
#
# =================================================================
# Total params: 722282 (2.76 MB)
# Trainable params: 722282 (2.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def get_flops(model, input_shape):
    # Create a concrete function from the Keras model
    @tf.function
    def model_func(x):
        return model(x)
    
    # Get the concrete function
    concrete_func = model_func.get_concrete_function(tf.TensorSpec(input_shape, model.inputs[0].dtype))
    
    # Convert variables to constants and get the frozen graph
    frozen_func = convert_variables_to_constants_v2(concrete_func)
    frozen_graph = frozen_func.graph.as_graph_def()
    
    # Use TensorFlow's profiler
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(frozen_graph, name='')
        run_meta = tf.compat.v1.RunMetadata()
        with tf.compat.v1.Session(graph=graph) as sess:
            flops = tf.compat.v1.profiler.profile(
                graph=graph,
                run_meta=run_meta,
                cmd='op',
                options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
            )
            return flops.total_float_ops

# %%
'''for i in model_list:
    i.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    i.fit(X, y_one_hot, epochs=100, batch_size=2)
    loss_list.append(i.evaluate(X, y_one_hot)[0])
    accuracy_list.append(i.evaluate(X, y_one_hot)[1])'''
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, epochs=100, batch_size=64, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/100
# 2024-10-29 19:29:09.052943: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-10-29 19:29:09.182869: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-10-29 19:29:09.979999: I external/local_xla/xla/service/service.cc:168] XLA service 0x78912ac3b060 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-29 19:29:09.980016: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2024-10-29 19:29:09.987412: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730197750.049468 1325233 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 625/625 [==============================] - 9s 7ms/step - loss: 1.8092 - accuracy: 0.3170 - val_loss: 1.4661 - val_accuracy: 0.4496
# Epoch 2/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.3848 - accuracy: 0.4899 - val_loss: 1.2509 - val_accuracy: 0.5447
# Epoch 3/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.1700 - accuracy: 0.5779 - val_loss: 1.0296 - val_accuracy: 0.6314
# Epoch 4/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.0426 - accuracy: 0.6264 - val_loss: 0.9373 - val_accuracy: 0.6698
# Epoch 5/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.9433 - accuracy: 0.6651 - val_loss: 0.8249 - val_accuracy: 0.7082
# Epoch 6/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.8635 - accuracy: 0.6934 - val_loss: 0.8256 - val_accuracy: 0.6997
# Epoch 7/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.8063 - accuracy: 0.7159 - val_loss: 0.7457 - val_accuracy: 0.7318
# Epoch 8/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.7573 - accuracy: 0.7326 - val_loss: 0.7326 - val_accuracy: 0.7470
# Epoch 9/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.7263 - accuracy: 0.7458 - val_loss: 0.6657 - val_accuracy: 0.7700
# Epoch 10/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.6855 - accuracy: 0.7620 - val_loss: 0.6691 - val_accuracy: 0.7648
# Epoch 11/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.6556 - accuracy: 0.7695 - val_loss: 0.6975 - val_accuracy: 0.7595
# Epoch 12/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.6373 - accuracy: 0.7782 - val_loss: 0.6385 - val_accuracy: 0.7810
# Epoch 13/100
# 625/625 [==============================] - 5s 9ms/step - loss: 0.6116 - accuracy: 0.7859 - val_loss: 0.6260 - val_accuracy: 0.7858
# Epoch 14/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.5924 - accuracy: 0.7919 - val_loss: 0.6641 - val_accuracy: 0.7731
# Epoch 15/100
# 625/625 [==============================] - 5s 9ms/step - loss: 0.5767 - accuracy: 0.7981 - val_loss: 0.6050 - val_accuracy: 0.7899
# Epoch 16/100
# 625/625 [==============================] - 6s 10ms/step - loss: 0.5535 - accuracy: 0.8049 - val_loss: 0.6167 - val_accuracy: 0.7897
# Epoch 17/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.5438 - accuracy: 0.8084 - val_loss: 0.6309 - val_accuracy: 0.7822
# Epoch 18/100
# 625/625 [==============================] - 6s 9ms/step - loss: 0.5369 - accuracy: 0.8103 - val_loss: 0.6239 - val_accuracy: 0.7865
# Epoch 19/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.5201 - accuracy: 0.8169 - val_loss: 0.6111 - val_accuracy: 0.7891
# Epoch 20/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.5065 - accuracy: 0.8214 - val_loss: 0.5945 - val_accuracy: 0.7957
# Epoch 21/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.5001 - accuracy: 0.8255 - val_loss: 0.5895 - val_accuracy: 0.8004
# Epoch 22/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.
100
# 625/625 [==============================] - 5s 9ms/step - loss: 0.2755 - accuracy: 0.9062 - val_loss: 0.5949 - val_accuracy: 0.8266
# Epoch 84/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2640 - accuracy: 0.9112 - val_loss: 0.6585 - val_accuracy: 0.8154
# Epoch 85/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2644 - accuracy: 0.9103 - val_loss: 0.6338 - val_accuracy: 0.8231
# Epoch 86/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2651 - accuracy: 0.9096 - val_loss: 0.5846 - val_accuracy: 0.8339
# Epoch 87/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2580 - accuracy: 0.9121 - val_loss: 0.6280 - val_accuracy: 0.8241
# Epoch 88/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2577 - accuracy: 0.9116 - val_loss: 0.6001 - val_accuracy: 0.8271
# Epoch 89/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2577 - accuracy: 0.9132 - val_loss: 0.5985 - val_accuracy: 0.8289
# Epoch 90/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2661 - accuracy: 0.9081 - val_loss: 0.6063 - val_accuracy: 0.8288
# Epoch 91/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2489 - accuracy: 0.9163 - val_loss: 0.6190 - val_accuracy: 0.8256
# Epoch 92/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2637 - accuracy: 0.9105 - val_loss: 0.6260 - val_accuracy: 0.8285
# Epoch 93/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2514 - accuracy: 0.9146 - val_loss: 0.6027 - val_accuracy: 0.8245
# Epoch 94/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.2439 - accuracy: 0.9184 - val_loss: 0.6151 - val_accuracy: 0.8253
# Epoch 95/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2589 - accuracy: 0.9137 - val_loss: 0.6058 - val_accuracy: 0.8295
# Epoch 96/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2489 - accuracy: 0.9157 - val_loss: 0.5837 - val_accuracy: 0.8342
# Epoch 97/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2465 - accuracy: 0.9184 - val_loss: 0.6037 - val_accuracy: 0.8310
# Epoch 98/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2583 - accuracy: 0.9146 - val_loss: 0.6275 - val_accuracy: 0.8231
# Epoch 99/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2481 - accuracy: 0.9172 - val_loss: 0.6264 - val_accuracy: 0.8291
# Epoch 100/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2483 - accuracy: 0.9170 - val_loss: 0.6180 - val_accuracy: 0.8264

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.6310 - accuracy: 0.8268 - 685ms/epoch - 2ms/step

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()

# %%
#for idx, model in enumerate(model_list):
#    model.save(f'model_{idx}.h5')
get_flops(model, train_images.shape)
# Out:
# WARNING:tensorflow:From /home/am/Documents/VirtualEnv/tensorflow-gpu/lib/python3.11/site-packages/tensorflow/python/ops/nn_ops.py:5256: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# 2024-10-29 19:37:35.489512: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.489652: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-10-29 19:37:35.489728: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-10-29 19:37:35.489999: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.490133: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.490306: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.490431: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.490516: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.490572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9723 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-10-29 19:37:35.679596: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.679761: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.679839: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.679944: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.680020: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:37:35.680071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9723 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 3486576480000
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   3468.17b float_ops (100.00%, 99.47%)
# MatMul                   11.19b float_ops (0.53%, 0.32%)
# BiasAdd                  4.76b float_ops (0.21%, 0.14%)
# MaxPool                  2.46b float_ops (0.07%, 0.07%)
# Softmax                  2.00m float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================

# %%
def get_layer(model, layer_index):
    return [layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)][layer_index]

def get_filters(model, layer_index, filter_indices):
    layer = get_layer(model, layer_index)
    filters, biases = layer.get_weights()
    return filters[:, :, :, filter_indices]

def get_all_filters(model, layer_name):
    layer = model.get_layer(name=layer_name)
    filters, biases = layer.get_weights()
    return filters

# %%
get_all_filters(model, 'conv3').shape
# Out:
# (3, 3, 32, 64)

# %%
layer_name = 'conv3'
intermediate_model = models.Model(inputs=model.input, outputs=model.get_layer(layer_name).output)
feature_maps = intermediate_model.predict(train_images[:1000])

np.linalg.norm(feature_maps[:,:,:,31]) - np.linalg.norm(feature_maps)
# Out:
# 32/32 [==============================] - 0s 5ms/step
# -780.6161

# %%
feature_maps.shape
# Out:
# (1000, 16, 16, 64)

# %%
'''def norms(model_index, layer_index, model_list):    
    model_norm_list = []
    for model_idx, model in enumerate(model_list):
        #print(model_idx)
        layer_norm_list = []
        for layer_idx, layer in enumerate([layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)]):
            #print(layer_idx)
            norm_list = []
            filters, biases = layer.get_weights()
            num_filters = filters.shape[-1]
            for i in range(num_filters):
                
                filt = filters[:, :, :, i]
                filt_matrix = filt.reshape(-1, filt.shape[-1])
                norm = np.linalg.norm(filt_matrix)
                norm_list.append(norm)
            layer_norm_list.append(norm_list)
        model_norm_list.append(layer_norm_list)
    return model_norm_list[model_index][layer_index]'''

'''def get_norm(model, layer_name):
    layer = model.get_layer(layer_name)
    filters, biases = layer.get_weights()
    num_filters = filters.shape[-1]
    norms = []
    for i in range(num_filters):
        filt = filters[:, :, :, i]
        filt_matrix = filt.reshape(-1, filt.shape[-1])
        norm = np.linalg.norm(filt_matrix)
        norms.append(norm)
    return norms'''

'''def get_filter_uniqueness(model, layer_name):
    layer = model.get_layer(layer_name)
    filters, biases = layer.get_weights()
    num_filters = filters.shape[-1]
    uniqueness_list = []
    for i in range(num_filters):
        filt = filters[:, :, :, i]
        filt_matrix = filt.reshape(-1, filt.shape[-1])
        uniqueness = np.linalg.norm(filt_matrix) - np.linalg.norm(get_all_filters(model, layer_name))

        uniqueness_list.append(uniqueness)
    return uniqueness_list'''

def get_feature_map_uniqueness(model, layer_name):
    intermediate_model = models.Model(inputs=model.input, outputs=model.get_layer(layer_name).output)
    feature_maps = intermediate_model.predict(train_images[:1000])
    layer = model.get_layer(layer_name)
    filters, biases = layer.get_weights()
    num_filters = filters.shape[-1]
    feature_uniqueness_list = []
    for i in range(num_filters):
        feature_uniqueness_list.append(np.linalg.norm(feature_maps[:,:,:,i]) - np.linalg.norm(feature_maps))
    return feature_uniqueness_list





feat_unique_conv3 = get_feature_map_uniqueness(model, 'conv3')
feat_unique_conv4 = get_feature_map_uniqueness(model, 'conv4')
feat_unique_conv5 = get_feature_map_uniqueness(model, 'conv5')
feat_unique_conv6 = get_feature_map_uniqueness(model, 'conv6')
feat_unique_conv7 = get_feature_map_uniqueness(model, 'conv7')
# Out:
# 32/32 [==============================] - 0s 699us/step
# 32/32 [==============================] - 0s 4ms/step
# 32/32 [==============================] - 0s 4ms/step
# 32/32 [==============================] - 0s 4ms/step
# 32/32 [==============================] - 0s 4ms/step

# %%
def filter_to_zero(norms, percentage):
    threshold = np.percentile(norms, percentage)
    return [i for i, norm in enumerate(norms) if norm < threshold]

def filter_to_keep(norms, percentage):
    threshold = np.percentile(norms, percentage)
    return [i for i, norm in enumerate(norms) if norm >= threshold]

# %%
keep_filt_conv3 = filter_to_keep(feat_unique_conv3, 50)
keep_filt_conv4 = filter_to_keep(feat_unique_conv4, 50)
keep_filt_conv5 = filter_to_keep(feat_unique_conv5, 70)
keep_filt_conv6 = filter_to_keep(feat_unique_conv6, 70)
keep_filt_conv7 = filter_to_keep(feat_unique_conv7, 90)

# %%
'''pruned_target_model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=X.shape[1:], name='target_conv1'),
        MaxPooling2D((2,2), name='target_pool1'),
        Conv2D(len(keep_filt), (3,3), activation='relu', name='target_conv2'),
        MaxPooling2D((2,2), name='target_pool2'),
        Flatten(name='target_flatten'),
        Dense(len(keep_filt), activation='relu', name='target_fc1'),
        Dense(10, activation='softmax', name='target_output')
        ])'''

pruned_target_model = Sequential([
        Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3), name='conv1'),
        Conv2D(32, (3,3), activation='relu', padding='same', name='conv2'),
        MaxPooling2D((2,2), name='pool1'),
        Dropout(0.25),

        Conv2D(len(keep_filt_conv3), (3,3), activation='relu', padding='same', name='conv3'),
        Conv2D(len(keep_filt_conv4), (3,3), activation='relu', padding='same',  name='conv4'),
        MaxPooling2D((2,2), name='pool2'),
        Dropout(0.25),

        Conv2D(len(keep_filt_conv5), (3,3), activation='relu', padding='same',  name='conv5'),
        Conv2D(len(keep_filt_conv6), (3,3), activation='relu', padding='same',  name='conv6'),
        MaxPooling2D((2,2), name='pool3'),
        Dropout(0.25),

        Conv2D(len(keep_filt_conv7), (3,3), activation='relu', padding='same',  name='conv7'),
        MaxPooling2D((2,2), name='pool4'),
        Dropout(0.25),
        #Conv2D(128, (3,3), activation='relu', padding='same', name='conv5'),
        Flatten(name='flatten'),
        Dense(len(keep_filt_conv7), activation='relu', name='fc1'),
        Dense(64, activation='relu', name='fc2'),
        Dense(10, activation='softmax', name='output')
        ])

# %%
pruned_target_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  dropout_4 (Dropout)         (None, 16, 16, 32)        0
#
#  conv3 (Conv2D)              (None, 16, 16, 32)        9248
#
#  conv4 (Conv2D)              (None, 16, 16, 32)        9248
#
#  pool2 (MaxPooling2D)        (None, 8, 8, 32)          0
#
#  dropout_5 (Dropout)         (None, 8, 8, 32)          0
#
#  conv5 (Conv2D)              (None, 8, 8, 39)          11271
#
#  conv6 (Conv2D)              (None, 8, 8, 39)          13728
#
#  pool3 (MaxPooling2D)        (None, 4, 4, 39)          0
#
#  dropout_6 (Dropout)         (None, 4, 4, 39)          0
#
#  conv7 (Conv2D)              (None, 4, 4, 26)          9152
#
#  pool4 (MaxPooling2D)        (None, 2, 2, 26)          0
#
#  dropout_7 (Dropout)         (None, 2, 2, 26)          0
#
#  flatten (Flatten)           (None, 104)               0
#
#  fc1 (Dense)                 (None, 26)                2730
#
#  fc2 (Dense)                 (None, 64)                1728
#
#  output (Dense)              (None, 10)                650
#
# =================================================================
# Total params: 67899 (265.23 KB)
# Trainable params: 67899 (265.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
'''def copy_weights_pruned(source_model, pruned_target_model, source_layer_name, target_layer_name):
    for source_layer, target_layer in zip(source_model.layers, pruned_target_model.layers):
        if isinstance(source_layer, tf.keras.layers.Conv2D) and source_layer.name != source_layer_name and target_layer.name != target_layer_name:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w, b])
        elif source_layer.name == source_layer_name and target_layer.name == target_layer_name:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w[:, :, :, keep_filt], b[keep_filt]])'''
def get_var_name(var):
    for name, value in locals().items():
        if value is var:
            return name

def copy_weights_pruned(source_model, pruned_target_model, source_layer_names, target_layer_names, keep_filters):
    for source_layer, target_layer in zip(source_model.layers, pruned_target_model.layers):
        if isinstance(source_layer, tf.keras.layers.Conv2D) and source_layer.name not in source_layer_names and target_layer.name not in target_layer_names:
            w, b = source_layer.get_weights()
            target_layer.set_weights([w, b])
        elif source_layer.name in source_layer_names and target_layer.name in target_layer_names:
            for keep_filt in keep_filters:
                if source_layer.name in get_var_name(keep_filt):
                    w, b = source_layer.get_weights()
                    target_layer.set_weights([w[:, :, :, keep_filt], b[keep_filt]])

# %%
copy_weights_pruned(model, pruned_target_model, [ 'conv3', 'conv4', 'conv5', 'conv6', 'conv7'], [ 'conv3', 'conv4', 'conv5', 'conv6', 'conv7'], [ keep_filt_conv3, keep_filt_conv4, keep_filt_conv5, keep_filt_conv6, keep_filt_conv7])

# %%
pruned_target_model.get_layer('conv3').get_weights()[0].shape
# Out:
# (3, 3, 32, 32)

# %%
pruned_target_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = pruned_target_model.fit(train_images, train_labels, epochs=100, batch_size=64, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/100
# 2024-10-29 19:37:39.679470: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout_4/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 625/625 [==============================] - 6s 7ms/step - loss: 1.6849 - accuracy: 0.3464 - val_loss: 1.3497 - val_accuracy: 0.4913
# Epoch 2/100
# 625/625 [==============================] - 4s 6ms/step - loss: 1.2799 - accuracy: 0.5275 - val_loss: 1.0716 - val_accuracy: 0.6060
# Epoch 3/100
# 625/625 [==============================] - 4s 7ms/step - loss: 1.1073 - accuracy: 0.6047 - val_loss: 0.9438 - val_accuracy: 0.6702
# Epoch 4/100
# 625/625 [==============================] - 4s 6ms/step - loss: 1.0033 - accuracy: 0.6434 - val_loss: 0.9224 - val_accuracy: 0.6668
# Epoch 5/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.9461 - accuracy: 0.6650 - val_loss: 0.8283 - val_accuracy: 0.7005
# Epoch 6/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.9073 - accuracy: 0.6786 - val_loss: 0.8033 - val_accuracy: 0.7033
# Epoch 7/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.8743 - accuracy: 0.6894 - val_loss: 0.8152 - val_accuracy: 0.7073
# Epoch 8/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8506 - accuracy: 0.7017 - val_loss: 0.7707 - val_accuracy: 0.7203
# Epoch 9/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.8207 - accuracy: 0.7117 - val_loss: 0.7910 - val_accuracy: 0.7168
# Epoch 10/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.8025 - accuracy: 0.7188 - val_loss: 0.7360 - val_accuracy: 0.7384
# Epoch 11/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.7877 - accuracy: 0.7238 - val_loss: 0.7103 - val_accuracy: 0.7485
# Epoch 12/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7707 - accuracy: 0.7307 - val_loss: 0.7338 - val_accuracy: 0.7388
# Epoch 13/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7629 - accuracy: 0.7340 - val_loss: 0.6898 - val_accuracy: 0.7567
# Epoch 14/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7481 - accuracy: 0.7403 - val_loss: 0.6915 - val_accuracy: 0.7574
# Epoch 15/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7379 - accuracy: 0.7427 - val_loss: 0.6861 - val_accuracy: 0.7561
# Epoch 16/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7288 - accuracy: 0.7466 - val_loss: 0.6787 - val_accuracy: 0.7602
# Epoch 17/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7100 - accuracy: 0.7510 - val_loss: 0.6768 - val_accuracy: 0.7590
# Epoch 18/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7088 - accuracy: 0.7548 - val_loss: 0.6576 - val_accuracy: 0.7712
# Epoch 19/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.
100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5402 - accuracy: 0.8149 - val_loss: 0.5783 - val_accuracy: 0.8073
# Epoch 82/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.5440 - accuracy: 0.8125 - val_loss: 0.5736 - val_accuracy: 0.8069
# Epoch 83/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5352 - accuracy: 0.8179 - val_loss: 0.5604 - val_accuracy: 0.8082
# Epoch 84/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5388 - accuracy: 0.8159 - val_loss: 0.5502 - val_accuracy: 0.8155
# Epoch 85/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5316 - accuracy: 0.8158 - val_loss: 0.5738 - val_accuracy: 0.8068
# Epoch 86/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5412 - accuracy: 0.8126 - val_loss: 0.5533 - val_accuracy: 0.8149
# Epoch 87/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5324 - accuracy: 0.8179 - val_loss: 0.5916 - val_accuracy: 0.8033
# Epoch 88/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5319 - accuracy: 0.8185 - val_loss: 0.5549 - val_accuracy: 0.8163
# Epoch 89/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5282 - accuracy: 0.8186 - val_loss: 0.5612 - val_accuracy: 0.8101
# Epoch 90/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5292 - accuracy: 0.8181 - val_loss: 0.5817 - val_accuracy: 0.8057
# Epoch 91/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5335 - accuracy: 0.8171 - val_loss: 0.5914 - val_accuracy: 0.8022
# Epoch 92/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5275 - accuracy: 0.8190 - val_loss: 0.5497 - val_accuracy: 0.8157
# Epoch 93/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5251 - accuracy: 0.8182 - val_loss: 0.5606 - val_accuracy: 0.8141
# Epoch 94/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5273 - accuracy: 0.8171 - val_loss: 0.5731 - val_accuracy: 0.8082
# Epoch 95/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5308 - accuracy: 0.8173 - val_loss: 0.5415 - val_accuracy: 0.8165
# Epoch 96/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5186 - accuracy: 0.8205 - val_loss: 0.5712 - val_accuracy: 0.8072
# Epoch 97/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5247 - accuracy: 0.8196 - val_loss: 0.5602 - val_accuracy: 0.8117
# Epoch 98/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5236 - accuracy: 0.8185 - val_loss: 0.5724 - val_accuracy: 0.8094
# Epoch 99/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5202 - accuracy: 0.8209 - val_loss: 0.5639 - val_accuracy: 0.8095
# Epoch 100/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.5202 - accuracy: 0.8192 - val_loss: 0.6033 - val_accuracy: 0.7984

# %%
test_loss, test_acc = pruned_target_model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.6105 - accuracy: 0.7967 - 517ms/epoch - 2ms/step

# %%
get_flops(pruned_target_model, train_images.shape)
# Out:
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
# 2024-10-29 19:44:10.789227: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.789312: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-10-29 19:44:10.789359: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-10-29 19:44:10.789542: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.789629: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.789703: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.789806: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.789883: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.789934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9723 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2024-10-29 19:44:10.958336: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.958539: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.958675: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.958852: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.958987: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 19:44:10.959061: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9723 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# 1348172400000
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   1342.52b float_ops (100.00%, 99.58%)
# BiasAdd                  3.50b float_ops (0.42%, 0.26%)
# MaxPool                  1.75b float_ops (0.16%, 0.13%)
# MatMul                   400.64m float_ops (0.03%, 0.03%)
# Softmax                  2.00m float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

plt.show()

# %%
model.save('model_feature_uniqueness.h5')
pruned_target_model.save('pruned_target_model_feature_uniqueness.h5')
# Out:
# /home/am/Documents/VirtualEnv/tensorflow-gpu/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
